# %% [markdown]
# ## Installation des packages permettant la manipulation :
# - `dotenv` : Chargement des variables d'environnement
# - `requests` : Effectuer des requêtes HTTP
# - `pandas` : Créer et manipuler des DataFrames

# %%
# %pip install dotenv
# %pip install requests
# %pip install pandas
# Out:
# Requirement already satisfied: dotenv in ./.venv/lib/python3.12/site-packages (0.9.9)
# Requirement already satisfied: python-dotenv in ./.venv/lib/python3.12/site-packages (from dotenv) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: requests in ./.venv/lib/python3.12/site-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests) (2025.4.26)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in ./.venv/lib/python3.12/site-packages (2.3.0)
# Requirement already satisfied: numpy>=1.26.0 in ./.venv/lib/python3.12/site-packages (from pandas) (2.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Importation des packages permettant la manipulation :
# - Chargement des variables d'environnement avec `dotenv`
# - Récupération des variables d'environnement avec `os`
# - Éxécution de requête HTTP avec `requests`
# - Récupération et manipulation des dates avec `datetime`
# - Création et manipulation des DataFrames avec `pandas`

# %%
import dotenv
import os
import requests
import datetime
import pandas

# %% [markdown]
# ## Chargement et récupération des variables d'environnement

# %%
dotenv.load_dotenv()

NOTION_TOKEN = os.getenv("NOTION_TOKEN")
DB_INTERVENTIONS_ID = os.getenv("DB_INTERVENTIONS_ID")
DB_INVOICES_ID = os.getenv("DB_INVOICES_ID")

print( f"DB_INTERVENTIONS_ID : {DB_INTERVENTIONS_ID}\n"
      f"DB_INVOICES_ID : {DB_INVOICES_ID}")
# Out:
# DB_INTERVENTIONS_ID : 20f2cdbb475781db89c4c213335e99f4
# DB_INVOICES_ID : 20f2cdbb475781e7977bfdf28a148db6

# %% [markdown]
# # Étape 1 : Définir les entêtes pour l'API Notion

# %%
HEADERS = {
    "Authorization": f"Bearer {NOTION_TOKEN}",
    "Notion-Version": "2022-06-28",
    "Content-Type": "application/json",
}

# %% [markdown]
# Création d'une fonction permettant de récupérer les propriétés d'une base de données Notion à partir de son ID

# %%
def get_database_properties(database_id: str):
    url = f"https://api.notion.com/v1/databases/{database_id}"
    response = requests.get(url, headers=HEADERS)
    response.raise_for_status()
    return response.json()

# %%
get_database_properties(DB_INTERVENTIONS_ID)
# Out:
# {'object': 'database',
#  'id': '20f2cdbb-4757-81db-89c4-c213335e99f4',
#  'cover': None,
#  'icon': {'type': 'external',
#   'external': {'url': 'https://www.notion.so/icons/checkmark_green.svg'}},
#  'created_time': '2025-06-11T20:24:00.000Z',
#  'created_by': {'object': 'user',
#   'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#  'last_edited_by': {'object': 'user',
#   'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#  'last_edited_time': '2025-06-11T20:24:00.000Z',
#  'title': [{'type': 'text',
#    'text': {'content': 'Suivi des tâches', 'link': None},
#    'annotations': {'bold': False,
#     'italic': False,
#     'strikethrough': False,
#     'underline': False,
#     'code': False,
#     'color': 'default'},
#    'plain_text': 'Suivi des tâches',
#    'href': None}],
#  'description': [{'type': 'text',
#    'text': {'content': 'Restez organisé·e avec vos tâches, à votre façon.',
#     'link': None},
#    'annotations': {'bold': False,
#     'italic': False,
#     'strikethrough': False,
#     'underline': False,
#     'code': False,
#     'color': 'default'},
#    'plain_text': 'Restez organisé·e avec vos tâches, à votre façon.',
#    'href': None}],
#  'is_inline': True,
#  'properties': {'Ville': {'id': '%3Aso%7C',
#    'name': 'Ville',
#    'type': 'select',
#    'select': {'options': [{'id': '8a6b5b53-1dbd-4449-8c89-419f54def5a0',
#       'name': 'EPITECH Digital',
#       'color': 'purple',
#       'description': None},
#      {'id': '5381ceab-6724-46c2-932d-839395c80710',
#       'name': 'NEXA Digital School',
#       'color': 'brown',
#       'description': None},
#      {'id': '64c5008c-0326-4d4f-9e11-770b16d786c8',
#       'name': 'ENSIIE',
#       'color': 'orange',
#       'description': None},
#      {'id': 'e4fcc17a-ab67-43a0-a119-87b3f79e85fb',
#       'name': 'ESIEE',
#       'color': 'gray',
#       'description': None},
#      {'id': 'f19b6eb9-8259-4e8b-bf70-29e154dfac65',
#       'name': 'Le Kremlin-Bicêtre',
#       'color': 'default',
#       'description': None},
#      {'id': '174c7d92-91c1-4e88-8ece-42edf5f92c89',
#       'name': 'Evry',
#       'color': 'red',
#       'description': None},
#      {'id': 'd19a5c6d-abb8-42bd-9f83-de381e30fd50',
#       'name': 'Paris',
#       'color': 'green',
#       'description': None},
#      {'id': '1e5efd24-9bf4-4767-91c4-5724426627d7',
#       'name': 'Noisy-le-Grand',
#       'color': 'pink',
#       'description': None}]}},
#   'Niveau d’effort': {'id': '%3BoM%7C',
#    'name': 'Niveau d’effort',
#    'description': 'Combien de temps cela va-t-il prendre\xa0?',
#    'type': 'select',
#    'select': {'options': [{'id': '63decdf4-f0e6-4848-a1bf-561e68897381',
#       'name': 'Faible',
#       'color': 'green',
#       'description': None},
#      {'id': 'b537cf6c-8cb8-4c3f-9a10-132472389014',
#       'name': 'Moyenne',
#       'color': 'yellow',
#       'description': None},
#      {'id': '1993545d-653e-48d0-9496-cfc698410019',
#       'name': 'Élevé',
#       'color': 'red',
#       'description': None}]}},
#   'Classe': {'id': '%3D%3C%60%40',
#    'name': 'Classe',
#    'type': 'select',
#    'select': {'options': [{'id': '8a6b5b53-1dbd-4449-8c89-419f54def5a0',
#       'name': 'EPITECH Digital',
#       'color': 'purple',
#       'description': None},
#      {'id': '5381ceab-6724-46c2-932d-839395c80710',
#       'name': 'NEXA Digital School',
#       'color': 'brown',
#       'description': None},
#      {'id': 'f7b3a34a-b572-41c4-91c6-30e2937b691b',
#       'name': 'BTS SIO',
#       'color': 'red',
#       'description': None},
#      {'id': '76c26267-9e9f-4e8c-8631-44729b1c4de4',
#       'name': 'M2 EDWEB',
#       'color': 'pink',
#       'description': None},
#      {'id': '74f8f012-7bad-4d07-996e-6fe16dfe9fd7',
#       'name': 'M2 ESI',
#       'color': 'green',
#       'description': None},
#      {'id': 'b4f0bb80-bba0-4b83-886d-33e206db9eb6',
#       'name': 'M1',
#       'color': 'gray',
#       'description': None},
#      {'id': '6909ef26-d42f-4677-9602-b3789e59a4b1',
#       'name': 'L3',
#       'color': 'blue',
#       'description': None},
#      {'id': '1b1bcbf5-de31-41b5-8b09-f744c41741f1',
#       'name': 'M1 Maths',
#       'color': 'orange',
#       'description': None},
#      {'id': '926f38ae-5e57-4c95-a743-fdaca0551e3e',
#       'name': 'M1 EDWEB',
#       'color': 'default',
#       'description': None}]}},
#   'Date de fin': {'id': 'BC%7BD',
#    'name': 'Date de fin',
#    'type': 'date',
#    'date': {}},
#   'Total': {'id': 'E%5DAO',
#    'name': 'Total',
#    'type': 'formula',
#    'formula': {'expression': '{{notion:block_property:JjGy:00000000-0000-0000-0000-000000000000:36ecff02-3ea9-45e6-a160-9c4d034de0e9}}*{{notion:block_property:%60_Pc:00000000-0000-0000-0000-000000000000:36ecff02-3ea9-45e6-a160-9c4d034de0e9}}'}},
#   'Ecole': {'id': 'GDGQ',
#    'name': 'Ecole',
#    'type': 'select',
#    'select': {'options': [{'id': '8a6b5b53-1dbd-4449-8c89-419f54def5a0',
#       'name': 'EPITECH Digital',
#       'color': 'purple',
#       'description': None},
#      {'id': '5381ceab-6724-46c2-932d-839395c80710',
#       'name': 'NEXA Digital School',
#       'color': 'brown',
#       'description': None},
#      {'id': '64c5008c-0326-4d4f-9e11-770b16d786c8',
#       'name': 'ENSIIE',
#       'color': 'orange',
#       'description': None},
#      {'id': 'e4fcc17a-ab67-43a0-a119-87b3f79e85fb',
#       'name': 'ESIEE',
#       'color': 'gray',
#       'description': None},
#      {'id': 'dfbc5b84-5963-4a7b-a956-031282c6f02e',
#       'name': 'ECE',
#       'color': 'red',
#       'description': None}]}},
#   'Description': {'id': 'J%3AF%5B',
#    'name': 'Description',
#    'type': 'rich_text',
#    'rich_text': {}},
#   'Nombre heures': {'id': 'JjGy',
#    'name': 'Nombre heures',
#    'type': 'number',
#    'number': {'format': 'number'}},
#   'Type de tâche': {'id': 'L~%5D%3E',
#    'name': 'Type de tâche',
#    'type': 'select',
#    'select': {'options': [{'id': 'd6d80cdc-2ace-4648-91f9-0659634fdb28',
#       'name': 'Cours à préparer',
#       'color': 'yellow',
#       'description': None},
#      {'id': 'b5f73abd-0785-42dd-a3ae-7bbadbfb8089',
#       'name': 'Cours à présenter',
#       'color': 'default',
#       'description': None},
#      {'id': 'e692647e-d5dd-444e-a582-b43f159c6bcf',
#       'name': 'Cours présenté',
#       'color': 'green',
#       'description': None}]}},
#   'En souffrance': {'id': 'Ox~q',
#    'name': 'En souffrance',
#    'description': 'Signale les tâches qui ont dépassé leur date d’échéance',
#    'type': 'formula',
#    'formula': {'expression': 'if({{notion:block_property:hjFQ:00000000-0000-0000-0000-000000000000:36ecff02-3ea9-45e6-a160-9c4d034de0e9}} < now(),"⏰ Past Due", "")'}},
#   'Personne assignée': {'id': 'Qv%5Dw',
#    'name': 'Personne assignée',
#    'description': 'Qui est responsable du projet\xa0?',
#    'type': 'people',
#    'people': {}},
#   'État': {'id': 'S%5E%3Ed',
#    'name': 'État',
#    'type': 'status',
#    'status': {'options': [{'id': '2882bc4e-da9f-4eb2-a695-c9b64a3c9899',
#       'name': 'Pas commencé',
#       'color': 'default',
#       'description': None},
#      {'id': '59a26032-d447-44ed-9b17-7c9dec436fd3',
#       'name': 'En cours',
#       'color': 'blue',
#       'description': None},
#      {'id': '2150867b-0a8d-4a4e-9135-850e487ebad7',
#       'name': 'Terminé',
#       'color': 'green',
#       'description': None}],
#     'groups': [{'id': '94a7f3e8-9c67-4689-977b-266bad4c92d9',
#       'name': 'To-do',
#       'color': 'gray',
#       'option_ids': ['2882bc4e-da9f-4eb2-a695-c9b64a3c9899']},
#      {'id': 'fd9de969-3830-4e5d-b4ca-51ec4d98a801',
#       'name': 'In progress',
#       'color': 'blue',
#       'option_ids': ['59a26032-d447-44ed-9b17-7c9dec436fd3']},
#      {'id': 'bd5d4001-3eae-4fa0-bff3-b43b76e76557',
#       'name': 'Complete',
#       'color': 'green',
#       'option_ids': ['2150867b-0a8d-4a4e-9135-850e487ebad7']}]}},
#   'Facturé': {'id': 'UrM_',
#    'name': 'Facturé',
#    'type': 'checkbox',
#    'checkbox': {}},
#   'ID de facture': {'id': 'XMVJ',
#    'name': 'ID de facture',
#    'type': 'select',
#    'select': {'options': []}},
#   'Priorité': {'id': '%5EYGk',
#    'name': 'Priorité',
#    'type': 'select',
#    'select': {'options': [{'id': '31c883a7-33f8-470e-9176-8040a40106a4',
#       'name': 'Élevée',
#       'color': 'red',
#       'description': None},
#      {'id': '56939683-8650-4d96-91e1-0a9d1d1f4a13',
#       'name': 'Moyenne',
#       'color': 'yellow',
#       'description': None},
#      {'id': 'f16c66a7-64d9-4f1a-8eab-a965d86c01e6',
#       'name': 'Faible',
#       'color': 'green',
#       'description': None}]}},
#   'Tarif horaire': {'id': '%60_Pc',
#    'name': 'Tarif horaire',
#    'type': 'number',
#    'number': {'format': 'number'}},
#   'A facturer': {'id': 'dF%3AB',
#    'name': 'A facturer',
#    'type': 'select',
#    'select': {'options': [{'id': '17e6b388-ef96-4207-8404-78a6c92cbe26',
#       'name': 'Yes',
#       'color': 'green',
#       'description': None},
#      {'id': '941a32d3-abed-4a61-a63e-4cf323e13e92',
#       'name': 'No',
#       'color': 'pink',
#       'description': None},
#      {'id': 'd67cf60e-083f-48a0-a165-0a31c7710868',
#       'name': 'True',
#       'color': 'yellow',
#       'description': None},
#      {'id': 'e2ed5c32-9f2f-4c45-a567-486e828fa690',
#       'name': 'False',
#       'color': 'brown',
#       'description': None}]}},
#   'Date de début': {'id': 'hjFQ',
#    'name': 'Date de début',
#    'type': 'date',
#    'date': {}},
#   'Contenu de cours': {'id': 'rDxR',
#    'name': 'Contenu de cours',
#    'type': 'relation',
#    'relation': {'database_id': '20f2cdbb-4757-818c-a91e-c93877b2d981',
#     'type': 'single_property',
#     'single_property': {}}},
#   'Cours': {'id': 'title', 'name': 'Cours', 'type': 'title', 'title': {}}},
#  'parent': {'type': 'page_id',
#   'page_id': '20f2cdbb-4757-800f-94ff-c80f5a21836f'},
#  'url': 'https://www.notion.so/20f2cdbb475781db89c4c213335e99f4',
#  'public_url': 'https://tin-cloudberry-7b3.notion.site/20f2cdbb475781db89c4c213335e99f4',
#  'archived': False,
#  'in_trash': False,
#  'request_id': 'f9f66061-4131-4dae-87f6-7b26d5f3458f'}

# %%
get_database_properties(DB_INVOICES_ID)
# Out:
# {'object': 'database',
#  'id': '20f2cdbb-4757-81e7-977b-fdf28a148db6',
#  'cover': None,
#  'icon': None,
#  'created_time': '2025-06-11T20:24:00.000Z',
#  'created_by': {'object': 'user',
#   'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#  'last_edited_by': {'object': 'user',
#   'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#  'last_edited_time': '2025-06-11T20:24:00.000Z',
#  'title': [{'type': 'text',
#    'text': {'content': 'Invoices', 'link': None},
#    'annotations': {'bold': False,
#     'italic': False,
#     'strikethrough': False,
#     'underline': False,
#     'code': False,
#     'color': 'default'},
#    'plain_text': 'Invoices',
#    'href': None}],
#  'description': [],
#  'is_inline': True,
#  'properties': {'Mois': {'id': 'Jh%5EE',
#    'name': 'Mois',
#    'type': 'rich_text',
#    'rich_text': {}},
#   'Invoice Number': {'id': 'NoqM',
#    'name': 'Invoice Number',
#    'type': 'rich_text',
#    'rich_text': {}},
#   'Total Amount': {'id': 'xFzN',
#    'name': 'Total Amount',
#    'type': 'number',
#    'number': {'format': 'number'}},
#   'Client': {'id': 'title', 'name': 'Client', 'type': 'title', 'title': {}}},
#  'parent': {'type': 'page_id',
#   'page_id': '20f2cdbb-4757-800f-94ff-c80f5a21836f'},
#  'url': 'https://www.notion.so/20f2cdbb475781e7977bfdf28a148db6',
#  'public_url': 'https://tin-cloudberry-7b3.notion.site/20f2cdbb475781e7977bfdf28a148db6',
#  'archived': False,
#  'in_trash': False,
#  'request_id': '4bac3faf-9b56-4241-8b48-22032228835c'}

# %% [markdown]
# # Étape 2 : Fonction `query_unbilled_entries(date_begin: str, date_end: str, billed: bool)`

# %%
def query_unbilled_entries(date_begin: str, date_end: str, billed: bool = None):
    date_begin = datetime.datetime.strptime(date_begin, "%d/%m/%Y").isoformat()
    date_end = datetime.datetime.strptime(date_end, "%d/%m/%Y").isoformat()

    base_filters = [
        {"property": "Date de début", "date": {"on_or_after": f"{date_begin}"}}
    ]

    if billed is not None:
        base_filters.append({"property": "Facturé", "checkbox": {"equals": billed}})

    query = {
        "filter": {
            "and": base_filters + [{
                "or": [
                    {"property": "Date de fin", "date": {"before": f"{date_end}"}},
                    {"property": "Date de fin", "date": {"is_empty": True}}
                ]
            }]
        }
    }

    response = requests.post(
        f"https://api.notion.com/v1/databases/{DB_INTERVENTIONS_ID}/query",
        headers=HEADERS,
        json=query,
    )
    response.raise_for_status()
    return response.json()['results']

# %% [markdown]
# Exécution de la fonction permettant de récupérer les entrées non facturées

# %%
results = query_unbilled_entries("01/01/2023", "01/01/2026", False)
results
# Out:
# [{'object': 'page',
#   'id': '20f2cdbb-4757-818b-9f45-d151fc44e363',
#   'created_time': '2025-06-11T20:24:00.000Z',
#   'last_edited_time': '2025-06-11T20:24:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#   'last_edited_by': {'object': 'user',
#    'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#   'cover': None,
#   'icon': {'type': 'external',
#    'external': {'url': 'https://www.notion.so/icons/checkmark_green.svg'}},
#   'parent': {'type': 'database_id',
#    'database_id': '20f2cdbb-4757-81db-89c4-c213335e99f4'},
#   'archived': False,
#   'in_trash': False,
#   'properties': {'Ville': {'id': '%3Aso%7C',
#     'type': 'select',
#     'select': {'id': 'f19b6eb9-8259-4e8b-bf70-29e154dfac65',
#      'name': 'Le Kremlin-Bicêtre',
#      'color': 'default'}},
#    'Niveau d’effort': {'id': '%3BoM%7C',
#     'type': 'select',
#     'select': {'id': '1993545d-653e-48d0-9496-cfc698410019',
#      'name': 'Élevé',
#      'color': 'red'}},
#    'Classe': {'id': '%3D%3C%60%40',
#     'type': 'select',
#     'select': {'id': 'b4f0bb80-bba0-4b83-886d-33e206db9eb6',
#      'name': 'M1',
#      'color': 'gray'}},
#    'Date de fin': {'id': 'BC%7BD', 'type': 'date', 'date': None},
#    'Total': {'id': 'E%5DAO',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 70}},
#    'Ecole': {'id': 'GDGQ',
#     'type': 'select',
#     'select': {'id': '8a6b5b53-1dbd-4449-8c89-419f54def5a0',
#      'name': 'EPITECH Digital',
#      'color': 'purple'}},
#    'Description': {'id': 'J%3AF%5B', 'type': 'rich_text', 'rich_text': []},
#    'Nombre heures': {'id': 'JjGy', 'type': 'number', 'number': 7},
#    'Type de tâche': {'id': 'L~%5D%3E',
#     'type': 'select',
#     'select': {'id': 'e692647e-d5dd-444e-a582-b43f159c6bcf',
#      'name': 'Cours présenté',
#      'color': 'green'}},
#    'En souffrance': {'id': 'Ox~q',
#     'type': 'formula',
#     'formula': {'type': 'string', 'string': '⏰ Past Due'}},
#    'Personne assignée': {'id': 'Qv%5Dw', 'type': 'people', 'people': []},
#    'État': {'id': 'S%5E%3Ed',
#     'type': 'status',
#     'status': {'id': '2150867b-0a8d-4a4e-9135-850e487ebad7',
#      'name': 'Terminé',
#      'color': 'green'}},
#    'Facturé': {'id': 'UrM_', 'type': 'checkbox', 'checkbox': False},
#    'ID de facture': {'id': 'XMVJ', 'type': 'select', 'select': None},
#    'Priorité': {'id': '%5EYGk',
#     'type': 'select',
#     'select': {'id': '31c883a7-33f8-470e-9176-8040a40106a4',
#      'name': 'Élevée',
#      'color': 'red'}},
#    'Tarif horaire': {'id': '%60_Pc', 'type': 'number', 'number': 10},
#    'A facturer': {'id': 'dF%3AB',
#     'type': 'select',
#     'select': {'id': 'd67cf60e-083f-48a0-a165-0a31c7710868',
#      'name': 'True',
#      'color': 'yellow'}},
#    'Date de début': {'id': 'hjFQ',
#     'type': 'date',
#     'date': {'start': '2025-03-19', 'end': None, 'time_zone': None}},
#    'Contenu de cours': {'id': 'rDxR',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'Cours': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': ' Innovation en IA & Transformation des organisations partie 2',
#        'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': ' Innovation en IA & Transformation des organisations partie 2',
#       'href': None}]}},
#   'url': 'https://www.notion.so/Innovation-en-IA-Transformation-des-organisations-partie-2-20f2cdbb4757818b9f45d151fc44e363',
#   'public_url': 'https://tin-cloudberry-7b3.notion.site/Innovation-en-IA-Transformation-des-organisations-partie-2-20f2cdbb4757818b9f45d151fc44e363'},
#  {'object': 'page',
#   'id': '20f2cdbb-4757-8199-8878-e7a8cf86f749',
#   'created_time': '2025-06-11T20:24:00.000Z',
#   'last_edited_time': '2025-06-11T20:24:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#   'last_edited_by': {'object': 'user',
#    'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#   'cover': None,
#   'icon': {'type': 'external',
#    'external': {'url': 'https://www.notion.so/icons/checkmark_green.svg'}},
#   'parent': {'type': 'database_id',
#    'database_id': '20f2cdbb-4757-81db-89c4-c213335e99f4'},
#   'archived': False,
#   'in_trash': False,
#   'properties': {'Ville': {'id': '%3Aso%7C',
#     'type': 'select',
#     'select': {'id': '174c7d92-91c1-4e88-8ece-42edf5f92c89',
#      'name': 'Evry',
#      'color': 'red'}},
#    'Niveau d’effort': {'id': '%3BoM%7C',
#     'type': 'select',
#     'select': {'id': '1993545d-653e-48d0-9496-cfc698410019',
#      'name': 'Élevé',
#      'color': 'red'}},
#    'Classe': {'id': '%3D%3C%60%40',
#     'type': 'select',
#     'select': {'id': '1b1bcbf5-de31-41b5-8b09-f744c41741f1',
#      'name': 'M1 Maths',
#      'color': 'orange'}},
#    'Date de fin': {'id': 'BC%7BD', 'type': 'date', 'date': None},
#    'Total': {'id': 'E%5DAO',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 35}},
#    'Ecole': {'id': 'GDGQ',
#     'type': 'select',
#     'select': {'id': '64c5008c-0326-4d4f-9e11-770b16d786c8',
#      'name': 'ENSIIE',
#      'color': 'orange'}},
#    'Description': {'id': 'J%3AF%5B', 'type': 'rich_text', 'rich_text': []},
#    'Nombre heures': {'id': 'JjGy', 'type': 'number', 'number': 3.5},
#    'Type de tâche': {'id': 'L~%5D%3E',
#     'type': 'select',
#     'select': {'id': 'e692647e-d5dd-444e-a582-b43f159c6bcf',
#      'name': 'Cours présenté',
#      'color': 'green'}},
#    'En souffrance': {'id': 'Ox~q',
#     'type': 'formula',
#     'formula': {'type': 'string', 'string': ''}},
#    'Personne assignée': {'id': 'Qv%5Dw', 'type': 'people', 'people': []},
#    'État': {'id': 'S%5E%3Ed',
#     'type': 'status',
#     'status': {'id': '2882bc4e-da9f-4eb2-a695-c9b64a3c9899',
#      'name': 'Pas commencé',
#      'color': 'default'}},
#    'Facturé': {'id': 'UrM_', 'type': 'checkbox', 'checkbox': False},
#    'ID de facture': {'id': 'XMVJ', 'type': 'select', 'select': None},
#    'Priorité': {'id': '%5EYGk',
#     'type': 'select',
#     'select': {'id': '56939683-8650-4d96-91e1-0a9d1d1f4a13',
#      'name': 'Moyenne',
#      'color': 'yellow'}},
#    'Tarif horaire': {'id': '%60_Pc', 'type': 'number', 'number': 10},
#    'A facturer': {'id': 'dF%3AB',
#     'type': 'select',
#     'select': {'id': 'e2ed5c32-9f2f-4c45-a567-486e828fa690',
#      'name': 'False',
#      'color': 'brown'}},
#    'Date de début': {'id': 'hjFQ',
#     'type': 'date',
#     'date': {'start': '2025-07-02', 'end': None, 'time_zone': None}},
#    'Contenu de cours': {'id': 'rDxR',
#     'type': 'relation',
#     'relation': [{'id': '20f2cdbb-4757-81e3-b2d5-f52e43046ff5'}],
#     'has_more': False},
#    'Cours': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'Régression linéaire session 3', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'Régression linéaire session 3',
#       'href': None}]}},
#   'url': 'https://www.notion.so/R-gression-lin-aire-session-3-20f2cdbb475781998878e7a8cf86f749',
#   'public_url': 'https://tin-cloudberry-7b3.notion.site/R-gression-lin-aire-session-3-20f2cdbb475781998878e7a8cf86f749'},
#  {'object': 'page',
#   'id': '20f2cdbb-4757-81a8-8555-c3f27eae11e4',
#   'created_time': '2025-06-11T20:24:00.000Z',
#   'last_edited_time': '2025-06-11T20:24:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#   'last_edited_by': {'object': 'user',
#    'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#   'cover': None,
#   'icon': {'type': 'external',
#    'external': {'url': 'https://www.notion.so/icons/checkmark_green.svg'}},
#   'parent': {'type': 'database_id',
#    'database_id': '20f2cdbb-4757-81db-89c4-c213335e99f4'},
#   'archived': False,
#   'in_trash': False,
#   'properties': {'Ville': {'id': '%3Aso%7C',
#     'type': 'select',
#     'select': {'id': 'd19a5c6d-abb8-42bd-9f83-de381e30fd50',
#      'name': 'Paris',
#      'color': 'green'}},
#    'Niveau d’effort': {'id': '%3BoM%7C',
#     'type': 'select',
#     'select': {'id': '1993545d-653e-48d0-9496-cfc698410019',
#      'name': 'Élevé',
#      'color': 'red'}},
#    'Classe': {'id': '%3D%3C%60%40',
#     'type': 'select',
#     'select': {'id': 'b4f0bb80-bba0-4b83-886d-33e206db9eb6',
#      'name': 'M1',
#      'color': 'gray'}},
#    'Date de fin': {'id': 'BC%7BD', 'type': 'date', 'date': None},
#    'Total': {'id': 'E%5DAO',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 70}},
#    'Ecole': {'id': 'GDGQ',
#     'type': 'select',
#     'select': {'id': 'dfbc5b84-5963-4a7b-a956-031282c6f02e',
#      'name': 'ECE',
#      'color': 'red'}},
#    'Description': {'id': 'J%3AF%5B', 'type': 'rich_text', 'rich_text': []},
#    'Nombre heures': {'id': 'JjGy', 'type': 'number', 'number': 7},
#    'Type de tâche': {'id': 'L~%5D%3E',
#     'type': 'select',
#     'select': {'id': 'e692647e-d5dd-444e-a582-b43f159c6bcf',
#      'name': 'Cours présenté',
#      'color': 'green'}},
#    'En souffrance': {'id': 'Ox~q',
#     'type': 'formula',
#     'formula': {'type': 'string', 'string': '⏰ Past Due'}},
#    'Personne assignée': {'id': 'Qv%5Dw', 'type': 'people', 'people': []},
#    'État': {'id': 'S%5E%3Ed',
#     'type': 'status',
#     'status': {'id': '2150867b-0a8d-4a4e-9135-850e487ebad7',
#      'name': 'Terminé',
#      'color': 'green'}},
#    'Facturé': {'id': 'UrM_', 'type': 'checkbox', 'checkbox': False},
#    'ID de facture': {'id': 'XMVJ', 'type': 'select', 'select': None},
#    'Priorité': {'id': '%5EYGk',
#     'type': 'select',
#     'select': {'id': '31c883a7-33f8-470e-9176-8040a40106a4',
#      'name': 'Élevée',
#      'color': 'red'}},
#    'Tarif horaire': {'id': '%60_Pc', 'type': 'number', 'number': 10},
#    'A facturer': {'id': 'dF%3AB',
#     'type': 'select',
#     'select': {'id': 'd67cf60e-083f-48a0-a165-0a31c7710868',
#      'name': 'True',
#      'color': 'yellow'}},
#    'Date de début': {'id': 'hjFQ',
#     'type': 'date',
#     'date': {'start': '2025-03-05', 'end': None, 'time_zone': None}},
#    'Contenu de cours': {'id': 'rDxR',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'Cours': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'Innovation en IA & Transformation des organisations partie 1',
#        'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'Innovation en IA & Transformation des organisations partie 1',
#       'href': None}]}},
#   'url': 'https://www.notion.so/Innovation-en-IA-Transformation-des-organisations-partie-1-20f2cdbb475781a88555c3f27eae11e4',
#   'public_url': 'https://tin-cloudberry-7b3.notion.site/Innovation-en-IA-Transformation-des-organisations-partie-1-20f2cdbb475781a88555c3f27eae11e4'},
#  {'object': 'page',
#   'id': '20f2cdbb-4757-81af-b782-e893ae4f185d',
#   'created_time': '2025-06-11T20:24:00.000Z',
#   'last_edited_time': '2025-06-11T20:24:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#   'last_edited_by': {'object': 'user',
#    'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#   'cover': None,
#   'icon': {'type': 'external',
#    'external': {'url': 'https://www.notion.so/icons/checkmark_green.svg'}},
#   'parent': {'type': 'database_id',
#    'database_id': '20f2cdbb-4757-81db-89c4-c213335e99f4'},
#   'archived': False,
#   'in_trash': False,
#   'properties': {'Ville': {'id': '%3Aso%7C',
#     'type': 'select',
#     'select': {'id': 'f19b6eb9-8259-4e8b-bf70-29e154dfac65',
#      'name': 'Le Kremlin-Bicêtre',
#      'color': 'default'}},
#    'Niveau d’effort': {'id': '%3BoM%7C',
#     'type': 'select',
#     'select': {'id': '1993545d-653e-48d0-9496-cfc698410019',
#      'name': 'Élevé',
#      'color': 'red'}},
#    'Classe': {'id': '%3D%3C%60%40',
#     'type': 'select',
#     'select': {'id': 'b4f0bb80-bba0-4b83-886d-33e206db9eb6',
#      'name': 'M1',
#      'color': 'gray'}},
#    'Date de fin': {'id': 'BC%7BD', 'type': 'date', 'date': None},
#    'Total': {'id': 'E%5DAO',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 70}},
#    'Ecole': {'id': 'GDGQ',
#     'type': 'select',
#     'select': {'id': '8a6b5b53-1dbd-4449-8c89-419f54def5a0',
#      'name': 'EPITECH Digital',
#      'color': 'purple'}},
#    'Description': {'id': 'J%3AF%5B', 'type': 'rich_text', 'rich_text': []},
#    'Nombre heures': {'id': 'JjGy', 'type': 'number', 'number': 7},
#    'Type de tâche': {'id': 'L~%5D%3E',
#     'type': 'select',
#     'select': {'id': 'e692647e-d5dd-444e-a582-b43f159c6bcf',
#      'name': 'Cours présenté',
#      'color': 'green'}},
#    'En souffrance': {'id': 'Ox~q',
#     'type': 'formula',
#     'formula': {'type': 'string', 'string': '⏰ Past Due'}},
#    'Personne assignée': {'id': 'Qv%5Dw', 'type': 'people', 'people': []},
#    'État': {'id': 'S%5E%3Ed',
#     'type': 'status',
#     'status': {'id': '2150867b-0a8d-4a4e-9135-850e487ebad7',
#      'name': 'Terminé',
#      'color': 'green'}},
#    'Facturé': {'id': 'UrM_', 'type': 'checkbox', 'checkbox': False},
#    'ID de facture': {'id': 'XMVJ', 'type': 'select', 'select': None},
#    'Priorité': {'id': '%5EYGk',
#     'type': 'select',
#     'select': {'id': '31c883a7-33f8-470e-9176-8040a40106a4',
#      'name': 'Élevée',
#      'color': 'red'}},
#    'Tarif horaire': {'id': '%60_Pc', 'type': 'number', 'number': 10},
#    'A facturer': {'id': 'dF%3AB',
#     'type': 'select',
#     'select': {'id': 'd67cf60e-083f-48a0-a165-0a31c7710868',
#      'name': 'True',
#      'color': 'yellow'}},
#    'Date de début': {'id': 'hjFQ',
#     'type': 'date',
#     'date': {'start': '2025-03-05', 'end': None, 'time_zone': None}},
#    'Contenu de cours': {'id': 'rDxR',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'Cours': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'Innovation en IA & Transformation des organisations partie 1',
#        'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'Innovation en IA & Transformation des organisations partie 1',
#       'href': None}]}},
#   'url': 'https://www.notion.so/Innovation-en-IA-Transformation-des-organisations-partie-1-20f2cdbb475781afb782e893ae4f185d',
#   'public_url': 'https://tin-cloudberry-7b3.notion.site/Innovation-en-IA-Transformation-des-organisations-partie-1-20f2cdbb475781afb782e893ae4f185d'},
#  {'object': 'page',
#   'id': '20f2cdbb-4757-811b-be57-db25f8771237',
#   'created_time': '2025-06-11T20:24:00.000Z',
#   'last_edited_time': '2025-06-11T20:24:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#   'last_edited_by': {'object': 'user',
#    'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#   'cover': None,
#   'icon': {'type': 'external',
#    'external': {'url': 'https://www.notion.so/icons/checkmark_green.svg'}},
#   'parent': {'type': 'database_id',
#    'database_id': '20f2cdbb-4757-81db-89c4-c213335e99f4'},
#   'archived': False,
#   'in_trash': False,
#   'properties': {'Ville': {'id': '%3Aso%7C',
#     'type': 'select',
#     'select': {'id': 'd19a5c6d-abb8-42bd-9f83-de381e30fd50',
#      'name': 'Paris',
#      'color': 'green'}},
#    'Niveau d’effort': {'id': '%3BoM%7C',
#     'type': 'select',
#     'select': {'id': '1993545d-653e-48d0-9496-cfc698410019',
#      'name': 'Élevé',
#      'color': 'red'}},
#    'Classe': {'id': '%3D%3C%60%40',
#     'type': 'select',
#     'select': {'id': '6909ef26-d42f-4677-9602-b3789e59a4b1',
#      'name': 'L3',
#      'color': 'blue'}},
#    'Date de fin': {'id': 'BC%7BD', 'type': 'date', 'date': None},
#    'Total': {'id': 'E%5DAO',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 52.5}},
#    'Ecole': {'id': 'GDGQ',
#     'type': 'select',
#     'select': {'id': 'dfbc5b84-5963-4a7b-a956-031282c6f02e',
#      'name': 'ECE',
#      'color': 'red'}},
#    'Description': {'id': 'J%3AF%5B', 'type': 'rich_text', 'rich_text': []},
#    'Nombre heures': {'id': 'JjGy', 'type': 'number', 'number': 3.5},
#    'Type de tâche': {'id': 'L~%5D%3E',
#     'type': 'select',
#     'select': {'id': 'e692647e-d5dd-444e-a582-b43f159c6bcf',
#      'name': 'Cours présenté',
#      'color': 'green'}},
#    'En souffrance': {'id': 'Ox~q',
#     'type': 'formula',
#     'formula': {'type': 'string', 'string': '⏰ Past Due'}},
#    'Personne assignée': {'id': 'Qv%5Dw', 'type': 'people', 'people': []},
#    'État': {'id': 'S%5E%3Ed',
#     'type': 'status',
#     'status': {'id': '2150867b-0a8d-4a4e-9135-850e487ebad7',
#      'name': 'Terminé',
#      'color': 'green'}},
#    'Facturé': {'id': 'UrM_', 'type': 'checkbox', 'checkbox': False},
#    'ID de facture': {'id': 'XMVJ', 'type': 'select', 'select': None},
#    'Priorité': {'id': '%5EYGk',
#     'type': 'select',
#     'select': {'id': '31c883a7-33f8-470e-9176-8040a40106a4',
#      'name': 'Élevée',
#      'color': 'red'}},
#    'Tarif horaire': {'id': '%60_Pc', 'type': 'number', 'number': 15},
#    'A facturer': {'id': 'dF%3AB',
#     'type': 'select',
#     'select': {'id': 'd67cf60e-083f-48a0-a165-0a31c7710868',
#      'name': 'True',
#      'color': 'yellow'}},
#    'Date de début': {'id': 'hjFQ',
#     'type': 'date',
#     'date': {'start': '2025-05-16', 'end': None, 'time_zone': None}},
#    'Contenu de cours': {'id': 'rDxR',
#     'type': 'relation',
#     'relation': [{'id': '20f2cdbb-4757-81e3-b2d5-f52e43046ff5'}],
#     'has_more': False},
#    'Cours': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'Mathématiques pour l’informatique session 2',
#        'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'Mathématiques pour l’informatique session 2',
#       'href': None}]}},
#   'url': 'https://www.notion.so/Math-matiques-pour-l-informatique-session-2-20f2cdbb4757811bbe57db25f8771237',
#   'public_url': 'https://tin-cloudberry-7b3.notion.site/Math-matiques-pour-l-informatique-session-2-20f2cdbb4757811bbe57db25f8771237'},
#  {'object': 'page',
#   'id': '20f2cdbb-4757-812f-a46b-d9096bfbe60b',
#   'created_time': '2025-06-11T20:24:00.000Z',
#   'last_edited_time': '2025-06-11T20:24:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#   'last_edited_by': {'object': 'user',
#    'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#   'cover': None,
#   'icon': {'type': 'external',
#    'external': {'url': 'https://www.notion.so/icons/checkmark_green.svg'}},
#   'parent': {'type': 'database_id',
#    'database_id': '20f2cdbb-4757-81db-89c4-c213335e99f4'},
#   'archived': False,
#   'in_trash': False,
#   'properties': {'Ville': {'id': '%3Aso%7C',
#     'type': 'select',
#     'select': {'id': 'd19a5c6d-abb8-42bd-9f83-de381e30fd50',
#      'name': 'Paris',
#      'color': 'green'}},
#    'Niveau d’effort': {'id': '%3BoM%7C',
#     'type': 'select',
#     'select': {'id': '1993545d-653e-48d0-9496-cfc698410019',
#      'name': 'Élevé',
#      'color': 'red'}},
#    'Classe': {'id': '%3D%3C%60%40',
#     'type': 'select',
#     'select': {'id': 'f7b3a34a-b572-41c4-91c6-30e2937b691b',
#      'name': 'BTS SIO',
#      'color': 'red'}},
#    'Date de fin': {'id': 'BC%7BD', 'type': 'date', 'date': None},
#    'Total': {'id': 'E%5DAO',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 52.5}},
#    'Ecole': {'id': 'GDGQ',
#     'type': 'select',
#     'select': {'id': '5381ceab-6724-46c2-932d-839395c80710',
#      'name': 'NEXA Digital School',
#      'color': 'brown'}},
#    'Description': {'id': 'J%3AF%5B', 'type': 'rich_text', 'rich_text': []},
#    'Nombre heures': {'id': 'JjGy', 'type': 'number', 'number': 3.5},
#    'Type de tâche': {'id': 'L~%5D%3E',
#     'type': 'select',
#     'select': {'id': 'e692647e-d5dd-444e-a582-b43f159c6bcf',
#      'name': 'Cours présenté',
#      'color': 'green'}},
#    'En souffrance': {'id': 'Ox~q',
#     'type': 'formula',
#     'formula': {'type': 'string', 'string': '⏰ Past Due'}},
#    'Personne assignée': {'id': 'Qv%5Dw', 'type': 'people', 'people': []},
#    'État': {'id': 'S%5E%3Ed',
#     'type': 'status',
#     'status': {'id': '2150867b-0a8d-4a4e-9135-850e487ebad7',
#      'name': 'Terminé',
#      'color': 'green'}},
#    'Facturé': {'id': 'UrM_', 'type': 'checkbox', 'checkbox': False},
#    'ID de facture': {'id': 'XMVJ', 'type': 'select', 'select': None},
#    'Priorité': {'id': '%5EYGk',
#     'type': 'select',
#     'select': {'id': '31c883a7-33f8-470e-9176-8040a40106a4',
#      'name': 'Élevée',
#      'color': 'red'}},
#    'Tarif horaire': {'id': '%60_Pc', 'type': 'number', 'number': 15},
#    'A facturer': {'id': 'dF%3AB',
#     'type': 'select',
#     'select': {'id': 'd67cf60e-083f-48a0-a165-0a31c7710868',
#      'name': 'True',
#      'color': 'yellow'}},
#    'Date de début': {'id': 'hjFQ',
#     'type': 'date',
#     'date': {'start': '2025-05-23', 'end': None, 'time_zone': None}},
#    'Contenu de cours': {'id': 'rDxR',
#     'type': 'relation',
#     'relation': [{'id': '20f2cdbb-4757-81e3-b2d5-f52e43046ff5'}],
#     'has_more': False},
#    'Cours': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'Mathématiques pour l’informatique session 2',
#        'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'Mathématiques pour l’informatique session 2',
#       'href': None}]}},
#   'url': 'https://www.notion.so/Math-matiques-pour-l-informatique-session-2-20f2cdbb4757812fa46bd9096bfbe60b',
#   'public_url': 'https://tin-cloudberry-7b3.notion.site/Math-matiques-pour-l-informatique-session-2-20f2cdbb4757812fa46bd9096bfbe60b'},
#  {'object': 'page',
#   'id': '20f2cdbb-4757-81ad-943f-dc8494514169',
#   'created_time': '2025-06-11T20:24:00.000Z',
#   'last_edited_time': '2025-06-11T20:24:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#   'last_edited_by': {'object': 'user',
#    'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#   'cover': None,
#   'icon': {'type': 'external',
#    'external': {'url': 'https://www.notion.so/icons/checkmark_green.svg'}},
#   'parent': {'type': 'database_id',
#    'database_id': '20f2cdbb-4757-81db-89c4-c213335e99f4'},
#   'archived': False,
#   'in_trash': False,
#   'properties': {'Ville': {'id': '%3Aso%7C',
#     'type': 'select',
#     'select': {'id': 'd19a5c6d-abb8-42bd-9f83-de381e30fd50',
#      'name': 'Paris',
#      'color': 'green'}},
#    'Niveau d’effort': {'id': '%3BoM%7C',
#     'type': 'select',
#     'select': {'id': '1993545d-653e-48d0-9496-cfc698410019',
#      'name': 'Élevé',
#      'color': 'red'}},
#    'Classe': {'id': '%3D%3C%60%40',
#     'type': 'select',
#     'select': {'id': 'f7b3a34a-b572-41c4-91c6-30e2937b691b',
#      'name': 'BTS SIO',
#      'color': 'red'}},
#    'Date de fin': {'id': 'BC%7BD', 'type': 'date', 'date': None},
#    'Total': {'id': 'E%5DAO',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 52.5}},
#    'Ecole': {'id': 'GDGQ',
#     'type': 'select',
#     'select': {'id': '5381ceab-6724-46c2-932d-839395c80710',
#      'name': 'NEXA Digital School',
#      'color': 'brown'}},
#    'Description': {'id': 'J%3AF%5B', 'type': 'rich_text', 'rich_text': []},
#    'Nombre heures': {'id': 'JjGy', 'type': 'number', 'number': 3.5},
#    'Type de tâche': {'id': 'L~%5D%3E',
#     'type': 'select',
#     'select': {'id': 'e692647e-d5dd-444e-a582-b43f159c6bcf',
#      'name': 'Cours présenté',
#      'color': 'green'}},
#    'En souffrance': {'id': 'Ox~q',
#     'type': 'formula',
#     'formula': {'type': 'string', 'string': ''}},
#    'Personne assignée': {'id': 'Qv%5Dw', 'type': 'people', 'people': []},
#    'État': {'id': 'S%5E%3Ed',
#     'type': 'status',
#     'status': {'id': '2882bc4e-da9f-4eb2-a695-c9b64a3c9899',
#      'name': 'Pas commencé',
#      'color': 'default'}},
#    'Facturé': {'id': 'UrM_', 'type': 'checkbox', 'checkbox': False},
#    'ID de facture': {'id': 'XMVJ', 'type': 'select', 'select': None},
#    'Priorité': {'id': '%5EYGk',
#     'type': 'select',
#     'select': {'id': '56939683-8650-4d96-91e1-0a9d1d1f4a13',
#      'name': 'Moyenne',
#      'color': 'yellow'}},
#    'Tarif horaire': {'id': '%60_Pc', 'type': 'number', 'number': 15},
#    'A facturer': {'id': 'dF%3AB',
#     'type': 'select',
#     'select': {'id': 'e2ed5c32-9f2f-4c45-a567-486e828fa690',
#      'name': 'False',
#      'color': 'brown'}},
#    'Date de début': {'id': 'hjFQ',
#     'type': 'date',
#     'date': {'start': '2025-07-09', 'end': None, 'time_zone': None}},
#    'Contenu de cours': {'id': 'rDxR',
#     'type': 'relation',
#     'relation': [{'id': '20f2cdbb-4757-81e3-b2d5-f52e43046ff5'}],
#     'has_more': False},
#    'Cours': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'Mathématiques pour l’informatique session 3',
#        'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'Mathématiques pour l’informatique session 3',
#       'href': None}]}},
#   'url': 'https://www.notion.so/Math-matiques-pour-l-informatique-session-3-20f2cdbb475781ad943fdc8494514169',
#   'public_url': 'https://tin-cloudberry-7b3.notion.site/Math-matiques-pour-l-informatique-session-3-20f2cdbb475781ad943fdc8494514169'},
#  {'object': 'page',
#   'id': '20f2cdbb-4757-81d3-bde5-ed17bb210cf2',
#   'created_time': '2025-06-11T20:24:00.000Z',
#   'last_edited_time': '2025-06-11T20:24:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#   'last_edited_by': {'object': 'user',
#    'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#   'cover': None,
#   'icon': {'type': 'external',
#    'external': {'url': 'https://www.notion.so/icons/checkmark_green.svg'}},
#   'parent': {'type': 'database_id',
#    'database_id': '20f2cdbb-4757-81db-89c4-c213335e99f4'},
#   'archived': False,
#   'in_trash': False,
#   'properties': {'Ville': {'id': '%3Aso%7C',
#     'type': 'select',
#     'select': {'id': '1e5efd24-9bf4-4767-91c4-5724426627d7',
#      'name': 'Noisy-le-Grand',
#      'color': 'pink'}},
#    'Niveau d’effort': {'id': '%3BoM%7C', 'type': 'select', 'select': None},
#    'Classe': {'id': '%3D%3C%60%40',
#     'type': 'select',
#     'select': {'id': '76c26267-9e9f-4e8c-8631-44729b1c4de4',
#      'name': 'M2 EDWEB',
#      'color': 'pink'}},
#    'Date de fin': {'id': 'BC%7BD',
#     'type': 'date',
#     'date': {'start': '2025-05-03', 'end': None, 'time_zone': None}},
#    'Total': {'id': 'E%5DAO',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 140}},
#    'Ecole': {'id': 'GDGQ',
#     'type': 'select',
#     'select': {'id': 'e4fcc17a-ab67-43a0-a119-87b3f79e85fb',
#      'name': 'ESIEE',
#      'color': 'gray'}},
#    'Description': {'id': 'J%3AF%5B', 'type': 'rich_text', 'rich_text': []},
#    'Nombre heures': {'id': 'JjGy', 'type': 'number', 'number': 28},
#    'Type de tâche': {'id': 'L~%5D%3E',
#     'type': 'select',
#     'select': {'id': 'e692647e-d5dd-444e-a582-b43f159c6bcf',
#      'name': 'Cours présenté',
#      'color': 'green'}},
#    'En souffrance': {'id': 'Ox~q',
#     'type': 'formula',
#     'formula': {'type': 'string', 'string': '⏰ Past Due'}},
#    'Personne assignée': {'id': 'Qv%5Dw', 'type': 'people', 'people': []},
#    'État': {'id': 'S%5E%3Ed',
#     'type': 'status',
#     'status': {'id': '2150867b-0a8d-4a4e-9135-850e487ebad7',
#      'name': 'Terminé',
#      'color': 'green'}},
#    'Facturé': {'id': 'UrM_', 'type': 'checkbox', 'checkbox': False},
#    'ID de facture': {'id': 'XMVJ', 'type': 'select', 'select': None},
#    'Priorité': {'id': '%5EYGk',
#     'type': 'select',
#     'select': {'id': '31c883a7-33f8-470e-9176-8040a40106a4',
#      'name': 'Élevée',
#      'color': 'red'}},
#    'Tarif horaire': {'id': '%60_Pc', 'type': 'number', 'number': 5},
#    'A facturer': {'id': 'dF%3AB',
#     'type': 'select',
#     'select': {'id': 'd67cf60e-083f-48a0-a165-0a31c7710868',
#      'name': 'True',
#      'color': 'yellow'}},
#    'Date de début': {'id': 'hjFQ',
#     'type': 'date',
#     'date': {'start': '2025-04-25', 'end': None, 'time_zone': None}},
#    'Contenu de cours': {'id': 'rDxR',
#     'type': 'relation',
#     'relation': [{'id': '20f2cdbb-4757-811e-9f11-c463255b8617'}],
#     'has_more': False},
#    'Cours': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'Programmation avec Python - Introduction',
#        'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'Programmation avec Python - Introduction',
#       'href': None}]}},
#   'url': 'https://www.notion.so/Programmation-avec-Python-Introduction-20f2cdbb475781d3bde5ed17bb210cf2',
#   'public_url': 'https://tin-cloudberry-7b3.notion.site/Programmation-avec-Python-Introduction-20f2cdbb475781d3bde5ed17bb210cf2'},
#  {'object': 'page',
#   'id': '20f2cdbb-4757-81f7-9987-d156a45a6548',
#   'created_time': '2025-06-11T20:24:00.000Z',
#   'last_edited_time': '2025-06-11T20:24:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#   'last_edited_by': {'object': 'user',
#    'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#   'cover': None,
#   'icon': {'type': 'external',
#    'external': {'url': 'https://www.notion.so/icons/checkmark_green.svg'}},
#   'parent': {'type': 'database_id',
#    'database_id': '20f2cdbb-4757-81db-89c4-c213335e99f4'},
#   'archived': False,
#   'in_trash': False,
#   'properties': {'Ville': {'id': '%3Aso%7C',
#     'type': 'select',
#     'select': {'id': '174c7d92-91c1-4e88-8ece-42edf5f92c89',
#      'name': 'Evry',
#      'color': 'red'}},
#    'Niveau d’effort': {'id': '%3BoM%7C',
#     'type': 'select',
#     'select': {'id': '1993545d-653e-48d0-9496-cfc698410019',
#      'name': 'Élevé',
#      'color': 'red'}},
#    'Classe': {'id': '%3D%3C%60%40',
#     'type': 'select',
#     'select': {'id': '1b1bcbf5-de31-41b5-8b09-f744c41741f1',
#      'name': 'M1 Maths',
#      'color': 'orange'}},
#    'Date de fin': {'id': 'BC%7BD', 'type': 'date', 'date': None},
#    'Total': {'id': 'E%5DAO',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 17.5}},
#    'Ecole': {'id': 'GDGQ',
#     'type': 'select',
#     'select': {'id': '64c5008c-0326-4d4f-9e11-770b16d786c8',
#      'name': 'ENSIIE',
#      'color': 'orange'}},
#    'Description': {'id': 'J%3AF%5B', 'type': 'rich_text', 'rich_text': []},
#    'Nombre heures': {'id': 'JjGy', 'type': 'number', 'number': 3.5},
#    'Type de tâche': {'id': 'L~%5D%3E',
#     'type': 'select',
#     'select': {'id': 'd6d80cdc-2ace-4648-91f9-0659634fdb28',
#      'name': 'Cours à préparer',
#      'color': 'yellow'}},
#    'En souffrance': {'id': 'Ox~q',
#     'type': 'formula',
#     'formula': {'type': 'string', 'string': ''}},
#    'Personne assignée': {'id': 'Qv%5Dw', 'type': 'people', 'people': []},
#    'État': {'id': 'S%5E%3Ed',
#     'type': 'status',
#     'status': {'id': '2882bc4e-da9f-4eb2-a695-c9b64a3c9899',
#      'name': 'Pas commencé',
#      'color': 'default'}},
#    'Facturé': {'id': 'UrM_', 'type': 'checkbox', 'checkbox': False},
#    'ID de facture': {'id': 'XMVJ', 'type': 'select', 'select': None},
#    'Priorité': {'id': '%5EYGk',
#     'type': 'select',
#     'select': {'id': '56939683-8650-4d96-91e1-0a9d1d1f4a13',
#      'name': 'Moyenne',
#      'color': 'yellow'}},
#    'Tarif horaire': {'id': '%60_Pc', 'type': 'number', 'number': 5},
#    'A facturer': {'id': 'dF%3AB',
#     'type': 'select',
#     'select': {'id': 'e2ed5c32-9f2f-4c45-a567-486e828fa690',
#      'name': 'False',
#      'color': 'brown'}},
#    'Date de début': {'id': 'hjFQ',
#     'type': 'date',
#     'date': {'start': '2025-08-07', 'end': None, 'time_zone': None}},
#    'Contenu de cours': {'id': 'rDxR',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'Cours': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'Mathématiques pour l’informatique session 4',
#        'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'Mathématiques pour l’informatique session 4',
#       'href': None}]}},
#   'url': 'https://www.notion.so/Math-matiques-pour-l-informatique-session-4-20f2cdbb475781f79987d156a45a6548',
#   'public_url': 'https://tin-cloudberry-7b3.notion.site/Math-matiques-pour-l-informatique-session-4-20f2cdbb475781f79987d156a45a6548'},
#  {'object': 'page',
#   'id': '20f2cdbb-4757-81f8-bde1-f27672d396dc',
#   'created_time': '2025-06-11T20:24:00.000Z',
#   'last_edited_time': '2025-06-11T20:24:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#   'last_edited_by': {'object': 'user',
#    'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#   'cover': None,
#   'icon': {'type': 'external',
#    'external': {'url': 'https://www.notion.so/icons/checkmark_green.svg'}},
#   'parent': {'type': 'database_id',
#    'database_id': '20f2cdbb-4757-81db-89c4-c213335e99f4'},
#   'archived': False,
#   'in_trash': False,
#   'properties': {'Ville': {'id': '%3Aso%7C',
#     'type': 'select',
#     'select': {'id': 'd19a5c6d-abb8-42bd-9f83-de381e30fd50',
#      'name': 'Paris',
#      'color': 'green'}},
#    'Niveau d’effort': {'id': '%3BoM%7C',
#     'type': 'select',
#     'select': {'id': '1993545d-653e-48d0-9496-cfc698410019',
#      'name': 'Élevé',
#      'color': 'red'}},
#    'Classe': {'id': '%3D%3C%60%40',
#     'type': 'select',
#     'select': {'id': 'b4f0bb80-bba0-4b83-886d-33e206db9eb6',
#      'name': 'M1',
#      'color': 'gray'}},
#    'Date de fin': {'id': 'BC%7BD', 'type': 'date', 'date': None},
#    'Total': {'id': 'E%5DAO',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 70}},
#    'Ecole': {'id': 'GDGQ',
#     'type': 'select',
#     'select': {'id': 'dfbc5b84-5963-4a7b-a956-031282c6f02e',
#      'name': 'ECE',
#      'color': 'red'}},
#    'Description': {'id': 'J%3AF%5B', 'type': 'rich_text', 'rich_text': []},
#    'Nombre heures': {'id': 'JjGy', 'type': 'number', 'number': 7},
#    'Type de tâche': {'id': 'L~%5D%3E',
#     'type': 'select',
#     'select': {'id': 'e692647e-d5dd-444e-a582-b43f159c6bcf',
#      'name': 'Cours présenté',
#      'color': 'green'}},
#    'En souffrance': {'id': 'Ox~q',
#     'type': 'formula',
#     'formula': {'type': 'string', 'string': '⏰ Past Due'}},
#    'Personne assignée': {'id': 'Qv%5Dw', 'type': 'people', 'people': []},
#    'État': {'id': 'S%5E%3Ed',
#     'type': 'status',
#     'status': {'id': '2150867b-0a8d-4a4e-9135-850e487ebad7',
#      'name': 'Terminé',
#      'color': 'green'}},
#    'Facturé': {'id': 'UrM_', 'type': 'checkbox', 'checkbox': False},
#    'ID de facture': {'id': 'XMVJ', 'type': 'select', 'select': None},
#    'Priorité': {'id': '%5EYGk',
#     'type': 'select',
#     'select': {'id': '31c883a7-33f8-470e-9176-8040a40106a4',
#      'name': 'Élevée',
#      'color': 'red'}},
#    'Tarif horaire': {'id': '%60_Pc', 'type': 'number', 'number': 10},
#    'A facturer': {'id': 'dF%3AB',
#     'type': 'select',
#     'select': {'id': 'd67cf60e-083f-48a0-a165-0a31c7710868',
#      'name': 'True',
#      'color': 'yellow'}},
#    'Date de début': {'id': 'hjFQ',
#     'type': 'date',
#     'date': {'start': '2025-03-19', 'end': None, 'time_zone': None}},
#    'Contenu de cours': {'id': 'rDxR',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'Cours': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': ' Innovation en IA & Transformation des organisations partie 2',
#        'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': ' Innovation en IA & Transformation des organisations partie 2',
#       'href': None}]}},
#   'url': 'https://www.notion.so/Innovation-en-IA-Transformation-des-organisations-partie-2-20f2cdbb475781f8bde1f27672d396dc',
#   'public_url': 'https://tin-cloudberry-7b3.notion.site/Innovation-en-IA-Transformation-des-organisations-partie-2-20f2cdbb475781f8bde1f27672d396dc'},
#  {'object': 'page',
#   'id': '20f2cdbb-4757-810e-ada7-d7257e956579',
#   'created_time': '2025-06-11T20:24:00.000Z',
#   'last_edited_time': '2025-06-11T20:24:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#   'last_edited_by': {'object': 'user',
#    'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#   'cover': None,
#   'icon': {'type': 'external',
#    'external': {'url': 'https://www.notion.so/icons/checkmark_green.svg'}},
#   'parent': {'type': 'database_id',
#    'database_id': '20f2cdbb-4757-81db-89c4-c213335e99f4'},
#   'archived': False,
#   'in_trash': False,
#   'properties': {'Ville': {'id': '%3Aso%7C',
#     'type': 'select',
#     'select': {'id': 'd19a5c6d-abb8-42bd-9f83-de381e30fd50',
#      'name': 'Paris',
#      'color': 'green'}},
#    'Niveau d’effort': {'id': '%3BoM%7C',
#     'type': 'select',
#     'select': {'id': '1993545d-653e-48d0-9496-cfc698410019',
#      'name': 'Élevé',
#      'color': 'red'}},
#    'Classe': {'id': '%3D%3C%60%40',
#     'type': 'select',
#     'select': {'id': '6909ef26-d42f-4677-9602-b3789e59a4b1',
#      'name': 'L3',
#      'color': 'blue'}},
#    'Date de fin': {'id': 'BC%7BD', 'type': 'date', 'date': None},
#    'Total': {'id': 'E%5DAO',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 52.5}},
#    'Ecole': {'id': 'GDGQ',
#     'type': 'select',
#     'select': {'id': 'dfbc5b84-5963-4a7b-a956-031282c6f02e',
#      'name': 'ECE',
#      'color': 'red'}},
#    'Description': {'id': 'J%3AF%5B', 'type': 'rich_text', 'rich_text': []},
#    'Nombre heures': {'id': 'JjGy', 'type': 'number', 'number': 3.5},
#    'Type de tâche': {'id': 'L~%5D%3E',
#     'type': 'select',
#     'select': {'id': 'd6d80cdc-2ace-4648-91f9-0659634fdb28',
#      'name': 'Cours à préparer',
#      'color': 'yellow'}},
#    'En souffrance': {'id': 'Ox~q',
#     'type': 'formula',
#     'formula': {'type': 'string', 'string': ''}},
#    'Personne assignée': {'id': 'Qv%5Dw', 'type': 'people', 'people': []},
#    'État': {'id': 'S%5E%3Ed',
#     'type': 'status',
#     'status': {'id': '2882bc4e-da9f-4eb2-a695-c9b64a3c9899',
#      'name': 'Pas commencé',
#      'color': 'default'}},
#    'Facturé': {'id': 'UrM_', 'type': 'checkbox', 'checkbox': False},
#    'ID de facture': {'id': 'XMVJ', 'type': 'select', 'select': None},
#    'Priorité': {'id': '%5EYGk',
#     'type': 'select',
#     'select': {'id': '56939683-8650-4d96-91e1-0a9d1d1f4a13',
#      'name': 'Moyenne',
#      'color': 'yellow'}},
#    'Tarif horaire': {'id': '%60_Pc', 'type': 'number', 'number': 15},
#    'A facturer': {'id': 'dF%3AB',
#     'type': 'select',
#     'select': {'id': 'e2ed5c32-9f2f-4c45-a567-486e828fa690',
#      'name': 'False',
#      'color': 'brown'}},
#    'Date de début': {'id': 'hjFQ',
#     'type': 'date',
#     'date': {'start': '2025-08-12', 'end': None, 'time_zone': None}},
#    'Contenu de cours': {'id': 'rDxR',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'Cours': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'Mathématiques pour l’informatique session 5',
#        'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'Mathématiques pour l’informatique session 5',
#       'href': None}]}},
#   'url': 'https://www.notion.so/Math-matiques-pour-l-informatique-session-5-20f2cdbb4757810eada7d7257e956579',
#   'public_url': 'https://tin-cloudberry-7b3.notion.site/Math-matiques-pour-l-informatique-session-5-20f2cdbb4757810eada7d7257e956579'},
#  {'object': 'page',
#   'id': '20f2cdbb-4757-8125-9dc5-d12b2fb771ae',
#   'created_time': '2025-06-11T20:24:00.000Z',
#   'last_edited_time': '2025-06-11T20:24:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#   'last_edited_by': {'object': 'user',
#    'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#   'cover': None,
#   'icon': {'type': 'external',
#    'external': {'url': 'https://www.notion.so/icons/checkmark_green.svg'}},
#   'parent': {'type': 'database_id',
#    'database_id': '20f2cdbb-4757-81db-89c4-c213335e99f4'},
#   'archived': False,
#   'in_trash': False,
#   'properties': {'Ville': {'id': '%3Aso%7C',
#     'type': 'select',
#     'select': {'id': '174c7d92-91c1-4e88-8ece-42edf5f92c89',
#      'name': 'Evry',
#      'color': 'red'}},
#    'Niveau d’effort': {'id': '%3BoM%7C',
#     'type': 'select',
#     'select': {'id': '63decdf4-f0e6-4848-a1bf-561e68897381',
#      'name': 'Faible',
#      'color': 'green'}},
#    'Classe': {'id': '%3D%3C%60%40',
#     'type': 'select',
#     'select': {'id': '1b1bcbf5-de31-41b5-8b09-f744c41741f1',
#      'name': 'M1 Maths',
#      'color': 'orange'}},
#    'Date de fin': {'id': 'BC%7BD', 'type': 'date', 'date': None},
#    'Total': {'id': 'E%5DAO',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 20}},
#    'Ecole': {'id': 'GDGQ',
#     'type': 'select',
#     'select': {'id': '64c5008c-0326-4d4f-9e11-770b16d786c8',
#      'name': 'ENSIIE',
#      'color': 'orange'}},
#    'Description': {'id': 'J%3AF%5B', 'type': 'rich_text', 'rich_text': []},
#    'Nombre heures': {'id': 'JjGy', 'type': 'number', 'number': 2},
#    'Type de tâche': {'id': 'L~%5D%3E',
#     'type': 'select',
#     'select': {'id': 'e692647e-d5dd-444e-a582-b43f159c6bcf',
#      'name': 'Cours présenté',
#      'color': 'green'}},
#    'En souffrance': {'id': 'Ox~q',
#     'type': 'formula',
#     'formula': {'type': 'string', 'string': ''}},
#    'Personne assignée': {'id': 'Qv%5Dw', 'type': 'people', 'people': []},
#    'État': {'id': 'S%5E%3Ed',
#     'type': 'status',
#     'status': {'id': '2882bc4e-da9f-4eb2-a695-c9b64a3c9899',
#      'name': 'Pas commencé',
#      'color': 'default'}},
#    'Facturé': {'id': 'UrM_', 'type': 'checkbox', 'checkbox': False},
#    'ID de facture': {'id': 'XMVJ', 'type': 'select', 'select': None},
#    'Priorité': {'id': '%5EYGk',
#     'type': 'select',
#     'select': {'id': 'f16c66a7-64d9-4f1a-8eab-a965d86c01e6',
#      'name': 'Faible',
#      'color': 'green'}},
#    'Tarif horaire': {'id': '%60_Pc', 'type': 'number', 'number': 10},
#    'A facturer': {'id': 'dF%3AB',
#     'type': 'select',
#     'select': {'id': 'e2ed5c32-9f2f-4c45-a567-486e828fa690',
#      'name': 'False',
#      'color': 'brown'}},
#    'Date de début': {'id': 'hjFQ',
#     'type': 'date',
#     'date': {'start': '2025-07-24', 'end': None, 'time_zone': None}},
#    'Contenu de cours': {'id': 'rDxR',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'Cours': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'Régression linéaire session 4', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'Régression linéaire session 4',
#       'href': None}]}},
#   'url': 'https://www.notion.so/R-gression-lin-aire-session-4-20f2cdbb475781259dc5d12b2fb771ae',
#   'public_url': 'https://tin-cloudberry-7b3.notion.site/R-gression-lin-aire-session-4-20f2cdbb475781259dc5d12b2fb771ae'},
#  {'object': 'page',
#   'id': '20f2cdbb-4757-8137-aa49-fbc35001b2dc',
#   'created_time': '2025-06-11T20:24:00.000Z',
#   'last_edited_time': '2025-06-11T20:24:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#   'last_edited_by': {'object': 'user',
#    'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#   'cover': None,
#   'icon': {'type': 'external',
#    'external': {'url': 'https://www.notion.so/icons/checkmark_green.svg'}},
#   'parent': {'type': 'database_id',
#    'database_id': '20f2cdbb-4757-81db-89c4-c213335e99f4'},
#   'archived': False,
#   'in_trash': False,
#   'properties': {'Ville': {'id': '%3Aso%7C',
#     'type': 'select',
#     'select': {'id': 'd19a5c6d-abb8-42bd-9f83-de381e30fd50',
#      'name': 'Paris',
#      'color': 'green'}},
#    'Niveau d’effort': {'id': '%3BoM%7C',
#     'type': 'select',
#     'select': {'id': '1993545d-653e-48d0-9496-cfc698410019',
#      'name': 'Élevé',
#      'color': 'red'}},
#    'Classe': {'id': '%3D%3C%60%40',
#     'type': 'select',
#     'select': {'id': '6909ef26-d42f-4677-9602-b3789e59a4b1',
#      'name': 'L3',
#      'color': 'blue'}},
#    'Date de fin': {'id': 'BC%7BD', 'type': 'date', 'date': None},
#    'Total': {'id': 'E%5DAO',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 52.5}},
#    'Ecole': {'id': 'GDGQ',
#     'type': 'select',
#     'select': {'id': 'dfbc5b84-5963-4a7b-a956-031282c6f02e',
#      'name': 'ECE',
#      'color': 'red'}},
#    'Description': {'id': 'J%3AF%5B', 'type': 'rich_text', 'rich_text': []},
#    'Nombre heures': {'id': 'JjGy', 'type': 'number', 'number': 3.5},
#    'Type de tâche': {'id': 'L~%5D%3E',
#     'type': 'select',
#     'select': {'id': 'e692647e-d5dd-444e-a582-b43f159c6bcf',
#      'name': 'Cours présenté',
#      'color': 'green'}},
#    'En souffrance': {'id': 'Ox~q',
#     'type': 'formula',
#     'formula': {'type': 'string', 'string': '⏰ Past Due'}},
#    'Personne assignée': {'id': 'Qv%5Dw', 'type': 'people', 'people': []},
#    'État': {'id': 'S%5E%3Ed',
#     'type': 'status',
#     'status': {'id': '2150867b-0a8d-4a4e-9135-850e487ebad7',
#      'name': 'Terminé',
#      'color': 'green'}},
#    'Facturé': {'id': 'UrM_', 'type': 'checkbox', 'checkbox': False},
#    'ID de facture': {'id': 'XMVJ', 'type': 'select', 'select': None},
#    'Priorité': {'id': '%5EYGk',
#     'type': 'select',
#     'select': {'id': '31c883a7-33f8-470e-9176-8040a40106a4',
#      'name': 'Élevée',
#      'color': 'red'}},
#    'Tarif horaire': {'id': '%60_Pc', 'type': 'number', 'number': 15},
#    'A facturer': {'id': 'dF%3AB',
#     'type': 'select',
#     'select': {'id': 'd67cf60e-083f-48a0-a165-0a31c7710868',
#      'name': 'True',
#      'color': 'yellow'}},
#    'Date de début': {'id': 'hjFQ',
#     'type': 'date',
#     'date': {'start': '2025-04-23', 'end': None, 'time_zone': None}},
#    'Contenu de cours': {'id': 'rDxR',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'Cours': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'Mathématiques pour l’informatique session 1 (1)',
#        'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'Mathématiques pour l’informatique session 1 (1)',
#       'href': None}]}},
#   'url': 'https://www.notion.so/Math-matiques-pour-l-informatique-session-1-1-20f2cdbb47578137aa49fbc35001b2dc',
#   'public_url': 'https://tin-cloudberry-7b3.notion.site/Math-matiques-pour-l-informatique-session-1-1-20f2cdbb47578137aa49fbc35001b2dc'},
#  {'object': 'page',
#   'id': '20f2cdbb-4757-813e-a159-c862d0db2398',
#   'created_time': '2025-06-11T20:24:00.000Z',
#   'last_edited_time': '2025-06-11T20:24:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#   'last_edited_by': {'object': 'user',
#    'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#   'cover': None,
#   'icon': {'type': 'external',
#    'external': {'url': 'https://www.notion.so/icons/checkmark_green.svg'}},
#   'parent': {'type': 'database_id',
#    'database_id': '20f2cdbb-4757-81db-89c4-c213335e99f4'},
#   'archived': False,
#   'in_trash': False,
#   'properties': {'Ville': {'id': '%3Aso%7C',
#     'type': 'select',
#     'select': {'id': '174c7d92-91c1-4e88-8ece-42edf5f92c89',
#      'name': 'Evry',
#      'color': 'red'}},
#    'Niveau d’effort': {'id': '%3BoM%7C', 'type': 'select', 'select': None},
#    'Classe': {'id': '%3D%3C%60%40',
#     'type': 'select',
#     'select': {'id': '926f38ae-5e57-4c95-a743-fdaca0551e3e',
#      'name': 'M1 EDWEB',
#      'color': 'default'}},
#    'Date de fin': {'id': 'BC%7BD',
#     'type': 'date',
#     'date': {'start': '2025-08-01', 'end': None, 'time_zone': None}},
#    'Total': {'id': 'E%5DAO',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 210}},
#    'Ecole': {'id': 'GDGQ',
#     'type': 'select',
#     'select': {'id': '64c5008c-0326-4d4f-9e11-770b16d786c8',
# ...
#    'Personne assignée': {'id': 'Qv%5Dw', 'type': 'people', 'people': []},
#    'État': {'id': 'S%5E%3Ed',
#     'type': 'status',
#     'status': {'id': '2150867b-0a8d-4a4e-9135-850e487ebad7',
#      'name': 'Terminé',
#      'color': 'green'}},
#    'Facturé': {'id': 'UrM_', 'type': 'checkbox', 'checkbox': False},
#    'ID de facture': {'id': 'XMVJ', 'type': 'select', 'select': None},
#    'Priorité': {'id': '%5EYGk',
#     'type': 'select',
#     'select': {'id': '31c883a7-33f8-470e-9176-8040a40106a4',
#      'name': 'Élevée',
#      'color': 'red'}},
#    'Tarif horaire': {'id': '%60_Pc', 'type': 'number', 'number': 5},
#    'A facturer': {'id': 'dF%3AB',
#     'type': 'select',
#     'select': {'id': 'd67cf60e-083f-48a0-a165-0a31c7710868',
#      'name': 'True',
#      'color': 'yellow'}},
#    'Date de début': {'id': 'hjFQ',
#     'type': 'date',
#     'date': {'start': '2025-04-23', 'end': None, 'time_zone': None}},
#    'Contenu de cours': {'id': 'rDxR',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'Cours': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'Mathématiques pour l’informatique session 1',
#        'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'Mathématiques pour l’informatique session 1',
#       'href': None}]}},
#   'url': 'https://www.notion.so/Math-matiques-pour-l-informatique-session-1-20f2cdbb475781a4a852f8e505a44ba4',
#   'public_url': 'https://tin-cloudberry-7b3.notion.site/Math-matiques-pour-l-informatique-session-1-20f2cdbb475781a4a852f8e505a44ba4'},
#  {'object': 'page',
#   'id': '20f2cdbb-4757-81aa-a79a-e83a823a95ef',
#   'created_time': '2025-06-11T20:24:00.000Z',
#   'last_edited_time': '2025-06-11T20:24:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#   'last_edited_by': {'object': 'user',
#    'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#   'cover': None,
#   'icon': {'type': 'external',
#    'external': {'url': 'https://www.notion.so/icons/checkmark_green.svg'}},
#   'parent': {'type': 'database_id',
#    'database_id': '20f2cdbb-4757-81db-89c4-c213335e99f4'},
#   'archived': False,
#   'in_trash': False,
#   'properties': {'Ville': {'id': '%3Aso%7C',
#     'type': 'select',
#     'select': {'id': 'd19a5c6d-abb8-42bd-9f83-de381e30fd50',
#      'name': 'Paris',
#      'color': 'green'}},
#    'Niveau d’effort': {'id': '%3BoM%7C',
#     'type': 'select',
#     'select': {'id': '1993545d-653e-48d0-9496-cfc698410019',
#      'name': 'Élevé',
#      'color': 'red'}},
#    'Classe': {'id': '%3D%3C%60%40',
#     'type': 'select',
#     'select': {'id': 'f7b3a34a-b572-41c4-91c6-30e2937b691b',
#      'name': 'BTS SIO',
#      'color': 'red'}},
#    'Date de fin': {'id': 'BC%7BD', 'type': 'date', 'date': None},
#    'Total': {'id': 'E%5DAO',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 52.5}},
#    'Ecole': {'id': 'GDGQ',
#     'type': 'select',
#     'select': {'id': 'dfbc5b84-5963-4a7b-a956-031282c6f02e',
#      'name': 'ECE',
#      'color': 'red'}},
#    'Description': {'id': 'J%3AF%5B', 'type': 'rich_text', 'rich_text': []},
#    'Nombre heures': {'id': 'JjGy', 'type': 'number', 'number': 3.5},
#    'Type de tâche': {'id': 'L~%5D%3E',
#     'type': 'select',
#     'select': {'id': 'e692647e-d5dd-444e-a582-b43f159c6bcf',
#      'name': 'Cours présenté',
#      'color': 'green'}},
#    'En souffrance': {'id': 'Ox~q',
#     'type': 'formula',
#     'formula': {'type': 'string', 'string': ''}},
#    'Personne assignée': {'id': 'Qv%5Dw', 'type': 'people', 'people': []},
#    'État': {'id': 'S%5E%3Ed',
#     'type': 'status',
#     'status': {'id': '2882bc4e-da9f-4eb2-a695-c9b64a3c9899',
#      'name': 'Pas commencé',
#      'color': 'default'}},
#    'Facturé': {'id': 'UrM_', 'type': 'checkbox', 'checkbox': False},
#    'ID de facture': {'id': 'XMVJ', 'type': 'select', 'select': None},
#    'Priorité': {'id': '%5EYGk',
#     'type': 'select',
#     'select': {'id': '56939683-8650-4d96-91e1-0a9d1d1f4a13',
#      'name': 'Moyenne',
#      'color': 'yellow'}},
#    'Tarif horaire': {'id': '%60_Pc', 'type': 'number', 'number': 15},
#    'A facturer': {'id': 'dF%3AB',
#     'type': 'select',
#     'select': {'id': 'e2ed5c32-9f2f-4c45-a567-486e828fa690',
#      'name': 'False',
#      'color': 'brown'}},
#    'Date de début': {'id': 'hjFQ',
#     'type': 'date',
#     'date': {'start': '2025-07-02', 'end': None, 'time_zone': None}},
#    'Contenu de cours': {'id': 'rDxR',
#     'type': 'relation',
#     'relation': [{'id': '20f2cdbb-4757-81e3-b2d5-f52e43046ff5'}],
#     'has_more': False},
#    'Cours': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'Mathématiques pour l’informatique session 3',
#        'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'Mathématiques pour l’informatique session 3',
#       'href': None}]}},
#   'url': 'https://www.notion.so/Math-matiques-pour-l-informatique-session-3-20f2cdbb475781aaa79ae83a823a95ef',
#   'public_url': 'https://tin-cloudberry-7b3.notion.site/Math-matiques-pour-l-informatique-session-3-20f2cdbb475781aaa79ae83a823a95ef'},
#  {'object': 'page',
#   'id': '20f2cdbb-4757-81c8-86db-ec783d30929e',
#   'created_time': '2025-06-11T20:24:00.000Z',
#   'last_edited_time': '2025-06-11T20:24:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#   'last_edited_by': {'object': 'user',
#    'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#   'cover': None,
#   'icon': {'type': 'external',
#    'external': {'url': 'https://www.notion.so/icons/checkmark_green.svg'}},
#   'parent': {'type': 'database_id',
#    'database_id': '20f2cdbb-4757-81db-89c4-c213335e99f4'},
#   'archived': False,
#   'in_trash': False,
#   'properties': {'Ville': {'id': '%3Aso%7C',
#     'type': 'select',
#     'select': {'id': 'd19a5c6d-abb8-42bd-9f83-de381e30fd50',
#      'name': 'Paris',
#      'color': 'green'}},
#    'Niveau d’effort': {'id': '%3BoM%7C',
#     'type': 'select',
#     'select': {'id': '1993545d-653e-48d0-9496-cfc698410019',
#      'name': 'Élevé',
#      'color': 'red'}},
#    'Classe': {'id': '%3D%3C%60%40',
#     'type': 'select',
#     'select': {'id': 'f7b3a34a-b572-41c4-91c6-30e2937b691b',
#      'name': 'BTS SIO',
#      'color': 'red'}},
#    'Date de fin': {'id': 'BC%7BD', 'type': 'date', 'date': None},
#    'Total': {'id': 'E%5DAO',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 52.5}},
#    'Ecole': {'id': 'GDGQ',
#     'type': 'select',
#     'select': {'id': '5381ceab-6724-46c2-932d-839395c80710',
#      'name': 'NEXA Digital School',
#      'color': 'brown'}},
#    'Description': {'id': 'J%3AF%5B', 'type': 'rich_text', 'rich_text': []},
#    'Nombre heures': {'id': 'JjGy', 'type': 'number', 'number': 3.5},
#    'Type de tâche': {'id': 'L~%5D%3E',
#     'type': 'select',
#     'select': {'id': 'd6d80cdc-2ace-4648-91f9-0659634fdb28',
#      'name': 'Cours à préparer',
#      'color': 'yellow'}},
#    'En souffrance': {'id': 'Ox~q',
#     'type': 'formula',
#     'formula': {'type': 'string', 'string': ''}},
#    'Personne assignée': {'id': 'Qv%5Dw', 'type': 'people', 'people': []},
#    'État': {'id': 'S%5E%3Ed',
#     'type': 'status',
#     'status': {'id': '2882bc4e-da9f-4eb2-a695-c9b64a3c9899',
#      'name': 'Pas commencé',
#      'color': 'default'}},
#    'Facturé': {'id': 'UrM_', 'type': 'checkbox', 'checkbox': False},
#    'ID de facture': {'id': 'XMVJ', 'type': 'select', 'select': None},
#    'Priorité': {'id': '%5EYGk',
#     'type': 'select',
#     'select': {'id': '56939683-8650-4d96-91e1-0a9d1d1f4a13',
#      'name': 'Moyenne',
#      'color': 'yellow'}},
#    'Tarif horaire': {'id': '%60_Pc', 'type': 'number', 'number': 15},
#    'A facturer': {'id': 'dF%3AB',
#     'type': 'select',
#     'select': {'id': 'e2ed5c32-9f2f-4c45-a567-486e828fa690',
#      'name': 'False',
#      'color': 'brown'}},
#    'Date de début': {'id': 'hjFQ',
#     'type': 'date',
#     'date': {'start': '2025-08-21', 'end': None, 'time_zone': None}},
#    'Contenu de cours': {'id': 'rDxR',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'Cours': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'Mathématiques pour l’informatique session 4',
#        'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'Mathématiques pour l’informatique session 4',
#       'href': None}]}},
#   'url': 'https://www.notion.so/Math-matiques-pour-l-informatique-session-4-20f2cdbb475781c886dbec783d30929e',
#   'public_url': 'https://tin-cloudberry-7b3.notion.site/Math-matiques-pour-l-informatique-session-4-20f2cdbb475781c886dbec783d30929e'},
#  {'object': 'page',
#   'id': '20f2cdbb-4757-8168-a666-d172ed5d5ad2',
#   'created_time': '2025-06-11T20:24:00.000Z',
#   'last_edited_time': '2025-06-11T20:24:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#   'last_edited_by': {'object': 'user',
#    'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#   'cover': None,
#   'icon': {'type': 'external',
#    'external': {'url': 'https://www.notion.so/icons/checkmark_green.svg'}},
#   'parent': {'type': 'database_id',
#    'database_id': '20f2cdbb-4757-81db-89c4-c213335e99f4'},
#   'archived': False,
#   'in_trash': False,
#   'properties': {'Ville': {'id': '%3Aso%7C',
#     'type': 'select',
#     'select': {'id': '174c7d92-91c1-4e88-8ece-42edf5f92c89',
#      'name': 'Evry',
#      'color': 'red'}},
#    'Niveau d’effort': {'id': '%3BoM%7C',
#     'type': 'select',
#     'select': {'id': '1993545d-653e-48d0-9496-cfc698410019',
#      'name': 'Élevé',
#      'color': 'red'}},
#    'Classe': {'id': '%3D%3C%60%40',
#     'type': 'select',
#     'select': {'id': '1b1bcbf5-de31-41b5-8b09-f744c41741f1',
#      'name': 'M1 Maths',
#      'color': 'orange'}},
#    'Date de fin': {'id': 'BC%7BD', 'type': 'date', 'date': None},
#    'Total': {'id': 'E%5DAO',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 17.5}},
#    'Ecole': {'id': 'GDGQ',
#     'type': 'select',
#     'select': {'id': '64c5008c-0326-4d4f-9e11-770b16d786c8',
#      'name': 'ENSIIE',
#      'color': 'orange'}},
#    'Description': {'id': 'J%3AF%5B', 'type': 'rich_text', 'rich_text': []},
#    'Nombre heures': {'id': 'JjGy', 'type': 'number', 'number': 3.5},
#    'Type de tâche': {'id': 'L~%5D%3E',
#     'type': 'select',
#     'select': {'id': 'd6d80cdc-2ace-4648-91f9-0659634fdb28',
#      'name': 'Cours à préparer',
#      'color': 'yellow'}},
#    'En souffrance': {'id': 'Ox~q',
#     'type': 'formula',
#     'formula': {'type': 'string', 'string': ''}},
#    'Personne assignée': {'id': 'Qv%5Dw', 'type': 'people', 'people': []},
#    'État': {'id': 'S%5E%3Ed',
#     'type': 'status',
#     'status': {'id': '2882bc4e-da9f-4eb2-a695-c9b64a3c9899',
#      'name': 'Pas commencé',
#      'color': 'default'}},
#    'Facturé': {'id': 'UrM_', 'type': 'checkbox', 'checkbox': False},
#    'ID de facture': {'id': 'XMVJ', 'type': 'select', 'select': None},
#    'Priorité': {'id': '%5EYGk',
#     'type': 'select',
#     'select': {'id': '56939683-8650-4d96-91e1-0a9d1d1f4a13',
#      'name': 'Moyenne',
#      'color': 'yellow'}},
#    'Tarif horaire': {'id': '%60_Pc', 'type': 'number', 'number': 5},
#    'A facturer': {'id': 'dF%3AB',
#     'type': 'select',
#     'select': {'id': 'e2ed5c32-9f2f-4c45-a567-486e828fa690',
#      'name': 'False',
#      'color': 'brown'}},
#    'Date de début': {'id': 'hjFQ',
#     'type': 'date',
#     'date': {'start': '2025-08-12', 'end': None, 'time_zone': None}},
#    'Contenu de cours': {'id': 'rDxR',
#     'type': 'relation',
#     'relation': [],
#     'has_more': False},
#    'Cours': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'Mathématiques pour l’informatique session 5',
#        'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'Mathématiques pour l’informatique session 5',
#       'href': None}]}},
#   'url': 'https://www.notion.so/Math-matiques-pour-l-informatique-session-5-20f2cdbb47578168a666d172ed5d5ad2',
#   'public_url': 'https://tin-cloudberry-7b3.notion.site/Math-matiques-pour-l-informatique-session-5-20f2cdbb47578168a666d172ed5d5ad2'},
#  {'object': 'page',
#   'id': '20f2cdbb-4757-8182-9e78-f60d21173b3d',
#   'created_time': '2025-06-11T20:24:00.000Z',
#   'last_edited_time': '2025-06-11T20:24:00.000Z',
#   'created_by': {'object': 'user',
#    'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#   'last_edited_by': {'object': 'user',
#    'id': '2f589f48-fe35-4317-8f84-345e601d4a44'},
#   'cover': None,
#   'icon': {'type': 'external',
#    'external': {'url': 'https://www.notion.so/icons/checkmark_green.svg'}},
#   'parent': {'type': 'database_id',
#    'database_id': '20f2cdbb-4757-81db-89c4-c213335e99f4'},
#   'archived': False,
#   'in_trash': False,
#   'properties': {'Ville': {'id': '%3Aso%7C',
#     'type': 'select',
#     'select': {'id': '174c7d92-91c1-4e88-8ece-42edf5f92c89',
#      'name': 'Evry',
#      'color': 'red'}},
#    'Niveau d’effort': {'id': '%3BoM%7C',
#     'type': 'select',
#     'select': {'id': '1993545d-653e-48d0-9496-cfc698410019',
#      'name': 'Élevé',
#      'color': 'red'}},
#    'Classe': {'id': '%3D%3C%60%40',
#     'type': 'select',
#     'select': {'id': '1b1bcbf5-de31-41b5-8b09-f744c41741f1',
#      'name': 'M1 Maths',
#      'color': 'orange'}},
#    'Date de fin': {'id': 'BC%7BD', 'type': 'date', 'date': None},
#    'Total': {'id': 'E%5DAO',
#     'type': 'formula',
#     'formula': {'type': 'number', 'number': 35}},
#    'Ecole': {'id': 'GDGQ',
#     'type': 'select',
#     'select': {'id': '64c5008c-0326-4d4f-9e11-770b16d786c8',
#      'name': 'ENSIIE',
#      'color': 'orange'}},
#    'Description': {'id': 'J%3AF%5B', 'type': 'rich_text', 'rich_text': []},
#    'Nombre heures': {'id': 'JjGy', 'type': 'number', 'number': 3.5},
#    'Type de tâche': {'id': 'L~%5D%3E',
#     'type': 'select',
#     'select': {'id': 'e692647e-d5dd-444e-a582-b43f159c6bcf',
#      'name': 'Cours présenté',
#      'color': 'green'}},
#    'En souffrance': {'id': 'Ox~q',
#     'type': 'formula',
#     'formula': {'type': 'string', 'string': '⏰ Past Due'}},
#    'Personne assignée': {'id': 'Qv%5Dw', 'type': 'people', 'people': []},
#    'État': {'id': 'S%5E%3Ed',
#     'type': 'status',
#     'status': {'id': '2150867b-0a8d-4a4e-9135-850e487ebad7',
#      'name': 'Terminé',
#      'color': 'green'}},
#    'Facturé': {'id': 'UrM_', 'type': 'checkbox', 'checkbox': False},
#    'ID de facture': {'id': 'XMVJ', 'type': 'select', 'select': None},
#    'Priorité': {'id': '%5EYGk',
#     'type': 'select',
#     'select': {'id': '31c883a7-33f8-470e-9176-8040a40106a4',
#      'name': 'Élevée',
#      'color': 'red'}},
#    'Tarif horaire': {'id': '%60_Pc', 'type': 'number', 'number': 10},
#    'A facturer': {'id': 'dF%3AB',
#     'type': 'select',
#     'select': {'id': 'd67cf60e-083f-48a0-a165-0a31c7710868',
#      'name': 'True',
#      'color': 'yellow'}},
#    'Date de début': {'id': 'hjFQ',
#     'type': 'date',
#     'date': {'start': '2025-05-16', 'end': None, 'time_zone': None}},
#    'Contenu de cours': {'id': 'rDxR',
#     'type': 'relation',
#     'relation': [{'id': '20f2cdbb-4757-81e3-b2d5-f52e43046ff5'}],
#     'has_more': False},
#    'Cours': {'id': 'title',
#     'type': 'title',
#     'title': [{'type': 'text',
#       'text': {'content': 'Régression linéaire session 2', 'link': None},
#       'annotations': {'bold': False,
#        'italic': False,
#        'strikethrough': False,
#        'underline': False,
#        'code': False,
#        'color': 'default'},
#       'plain_text': 'Régression linéaire session 2',
#       'href': None}]}},
#   'url': 'https://www.notion.so/R-gression-lin-aire-session-2-20f2cdbb475781829e78f60d21173b3d',
#   'public_url': 'https://tin-cloudberry-7b3.notion.site/R-gression-lin-aire-session-2-20f2cdbb475781829e78f60d21173b3d'}]

# %% [markdown]
# Récupération depuis la réponse JSON, des valeurs utiles

# %%
results_json = []
for result in results:
    results_json.append({
        "Ville": result['properties']['Ville']['select']['name'],
        "Classe": result['properties']['Classe']['select']['name'],
        "Date de fin": result['properties']['Date de fin']['date']['start'] if result['properties']['Date de fin']['date'] else None,
        "Total": result['properties']['Total']['formula']['number'],
        "Ecole": result['properties']['Ecole']['select']['name'],
        "Nombre heures": result['properties']['Nombre heures']['number'],
        "Facturé": result['properties']['Facturé']['checkbox'],
        "Tarif horaire": result['properties']['Tarif horaire']['number'],
        "A facturer": True if result['properties']['A facturer']['select']['name'] == "True" else False,
        "Date de début": result['properties']['Date de début']['date']['start'],
        "Cours": result['properties']['Cours']['title'][0]['plain_text'],
    })
results_json
# Out:
# [{'Ville': 'Le Kremlin-Bicêtre',
#   'Classe': 'M1',
#   'Date de fin': None,
#   'Total': 70,
#   'Ecole': 'EPITECH Digital',
#   'Nombre heures': 7,
#   'Facturé': False,
#   'Tarif horaire': 10,
#   'A facturer': True,
#   'Date de début': '2025-03-19',
#   'Cours': ' Innovation en IA & Transformation des organisations partie 2'},
#  {'Ville': 'Evry',
#   'Classe': 'M1 Maths',
#   'Date de fin': None,
#   'Total': 35,
#   'Ecole': 'ENSIIE',
#   'Nombre heures': 3.5,
#   'Facturé': False,
#   'Tarif horaire': 10,
#   'A facturer': False,
#   'Date de début': '2025-07-02',
#   'Cours': 'Régression linéaire session 3'},
#  {'Ville': 'Paris',
#   'Classe': 'M1',
#   'Date de fin': None,
#   'Total': 70,
#   'Ecole': 'ECE',
#   'Nombre heures': 7,
#   'Facturé': False,
#   'Tarif horaire': 10,
#   'A facturer': True,
#   'Date de début': '2025-03-05',
#   'Cours': 'Innovation en IA & Transformation des organisations partie 1'},
#  {'Ville': 'Le Kremlin-Bicêtre',
#   'Classe': 'M1',
#   'Date de fin': None,
#   'Total': 70,
#   'Ecole': 'EPITECH Digital',
#   'Nombre heures': 7,
#   'Facturé': False,
#   'Tarif horaire': 10,
#   'A facturer': True,
#   'Date de début': '2025-03-05',
#   'Cours': 'Innovation en IA & Transformation des organisations partie 1'},
#  {'Ville': 'Paris',
#   'Classe': 'L3',
#   'Date de fin': None,
#   'Total': 52.5,
#   'Ecole': 'ECE',
#   'Nombre heures': 3.5,
#   'Facturé': False,
#   'Tarif horaire': 15,
#   'A facturer': True,
#   'Date de début': '2025-05-16',
#   'Cours': 'Mathématiques pour l’informatique session 2'},
#  {'Ville': 'Paris',
#   'Classe': 'BTS SIO',
#   'Date de fin': None,
#   'Total': 52.5,
#   'Ecole': 'NEXA Digital School',
#   'Nombre heures': 3.5,
#   'Facturé': False,
#   'Tarif horaire': 15,
#   'A facturer': True,
#   'Date de début': '2025-05-23',
#   'Cours': 'Mathématiques pour l’informatique session 2'},
#  {'Ville': 'Paris',
#   'Classe': 'BTS SIO',
#   'Date de fin': None,
#   'Total': 52.5,
#   'Ecole': 'NEXA Digital School',
#   'Nombre heures': 3.5,
#   'Facturé': False,
#   'Tarif horaire': 15,
#   'A facturer': False,
#   'Date de début': '2025-07-09',
#   'Cours': 'Mathématiques pour l’informatique session 3'},
#  {'Ville': 'Noisy-le-Grand',
#   'Classe': 'M2 EDWEB',
#   'Date de fin': '2025-05-03',
#   'Total': 140,
#   'Ecole': 'ESIEE',
#   'Nombre heures': 28,
#   'Facturé': False,
#   'Tarif horaire': 5,
#   'A facturer': True,
#   'Date de début': '2025-04-25',
#   'Cours': 'Programmation avec Python - Introduction'},
#  {'Ville': 'Evry',
#   'Classe': 'M1 Maths',
#   'Date de fin': None,
#   'Total': 17.5,
#   'Ecole': 'ENSIIE',
#   'Nombre heures': 3.5,
#   'Facturé': False,
#   'Tarif horaire': 5,
#   'A facturer': False,
#   'Date de début': '2025-08-07',
#   'Cours': 'Mathématiques pour l’informatique session 4'},
#  {'Ville': 'Paris',
#   'Classe': 'M1',
#   'Date de fin': None,
#   'Total': 70,
#   'Ecole': 'ECE',
#   'Nombre heures': 7,
#   'Facturé': False,
#   'Tarif horaire': 10,
#   'A facturer': True,
#   'Date de début': '2025-03-19',
#   'Cours': ' Innovation en IA & Transformation des organisations partie 2'},
#  {'Ville': 'Paris',
#   'Classe': 'L3',
#   'Date de fin': None,
#   'Total': 52.5,
#   'Ecole': 'ECE',
#   'Nombre heures': 3.5,
#   'Facturé': False,
#   'Tarif horaire': 15,
#   'A facturer': False,
#   'Date de début': '2025-08-12',
#   'Cours': 'Mathématiques pour l’informatique session 5'},
#  {'Ville': 'Evry',
#   'Classe': 'M1 Maths',
#   'Date de fin': None,
#   'Total': 20,
#   'Ecole': 'ENSIIE',
#   'Nombre heures': 2,
#   'Facturé': False,
#   'Tarif horaire': 10,
#   'A facturer': False,
#   'Date de début': '2025-07-24',
#   'Cours': 'Régression linéaire session 4'},
#  {'Ville': 'Paris',
#   'Classe': 'L3',
#   'Date de fin': None,
#   'Total': 52.5,
#   'Ecole': 'ECE',
#   'Nombre heures': 3.5,
#   'Facturé': False,
#   'Tarif horaire': 15,
#   'A facturer': True,
#   'Date de début': '2025-04-23',
#   'Cours': 'Mathématiques pour l’informatique session 1 (1)'},
#  {'Ville': 'Evry',
#   'Classe': 'M1 EDWEB',
#   'Date de fin': '2025-08-01',
#   'Total': 210,
#   'Ecole': 'ENSIIE',
#   'Nombre heures': 14,
#   'Facturé': False,
#   'Tarif horaire': 15,
#   'A facturer': False,
#   'Date de début': '2025-07-31',
#   'Cours': 'Accessibilité des Données : Enjeux, Solutions et Bonnes Pratiques'},
#  {'Ville': 'Paris',
#   'Classe': 'L3',
#   'Date de fin': None,
#   'Total': 52.5,
#   'Ecole': 'ECE',
#   'Nombre heures': 3.5,
#   'Facturé': False,
#   'Tarif horaire': 15,
#   'A facturer': False,
#   'Date de début': '2025-08-07',
#   'Cours': 'Mathématiques pour l’informatique session 4'},
#  {'Ville': 'Paris',
#   'Classe': 'L3',
#   'Date de fin': '2025-07-30',
#   'Total': 210,
#   'Ecole': 'ECE',
#   'Nombre heures': 14,
#   'Facturé': False,
#   'Tarif horaire': 15,
#   'A facturer': False,
#   'Date de début': '2025-07-28',
#   'Cours': 'Accessibilité des Données : Enjeux, Solutions et Bonnes Pratiques'},
#  {'Ville': 'Paris',
#   'Classe': 'BTS SIO',
#   'Date de fin': None,
#   'Total': 30,
#   'Ecole': 'NEXA Digital School',
#   'Nombre heures': 2,
#   'Facturé': False,
#   'Tarif horaire': 15,
#   'A facturer': False,
#   'Date de début': '2025-07-31',
#   'Cours': 'Mathématiques pour l’informatique examen blanc'},
#  {'Ville': 'Evry',
#   'Classe': 'L3',
#   'Date de fin': None,
#   'Total': 17.5,
#   'Ecole': 'ENSIIE',
#   'Nombre heures': 3.5,
#   'Facturé': False,
#   'Tarif horaire': 5,
#   'A facturer': False,
#   'Date de début': '2025-07-02',
#   'Cours': 'Mathématiques pour l’informatique session 3'},
#  {'Ville': 'Evry',
#   'Classe': 'L3',
#   'Date de fin': None,
#   'Total': 70,
#   'Ecole': 'ENSIIE',
#   'Nombre heures': 7,
#   'Facturé': False,
#   'Tarif horaire': 10,
#   'A facturer': False,
#   'Date de début': '2025-08-14',
#   'Cours': 'Régression linéaire soutenance'},
#  {'Ville': 'Evry',
#   'Classe': 'L3',
#   'Date de fin': None,
#   'Total': 35,
#   'Ecole': 'ENSIIE',
#   'Nombre heures': 3.5,
#   'Facturé': False,
#   'Tarif horaire': 10,
#   'A facturer': False,
#   'Date de début': '2025-08-07',
#   'Cours': 'Régression linéaire session 5'},
#  {'Ville': 'Paris',
#   'Classe': 'L3',
#   'Date de fin': None,
#   'Total': 30,
#   'Ecole': 'ECE',
#   'Nombre heures': 2,
#   'Facturé': False,
#   'Tarif horaire': 15,
#   'A facturer': False,
#   'Date de début': '2025-07-24',
#   'Cours': 'Mathématiques pour l’informatique examen blanc'},
#  {'Ville': 'Noisy-le-Grand',
#   'Classe': 'M1',
#   'Date de fin': '2025-06-13',
#   'Total': 140,
#   'Ecole': 'ESIEE',
#   'Nombre heures': 28,
#   'Facturé': False,
#   'Tarif horaire': 5,
#   'A facturer': False,
#   'Date de début': '2025-06-10',
#   'Cours': 'Programmation avec Python - Avancée (Orientée Data)'},
#  {'Ville': 'Noisy-le-Grand',
#   'Classe': 'M1',
#   'Date de fin': '2025-07-04',
#   'Total': 350,
#   'Ecole': 'ESIEE',
#   'Nombre heures': 35,
#   'Facturé': False,
#   'Tarif horaire': 10,
#   'A facturer': False,
#   'Date de début': '2025-06-30',
#   'Cours': " A la découverte du framework TensorFlow de Google pour construire des modèles d'IA"},
#  {'Ville': 'Le Kremlin-Bicêtre',
#   'Classe': 'M1',
#   'Date de fin': None,
#   'Total': 70,
#   'Ecole': 'EPITECH Digital',
#   'Nombre heures': 7,
#   'Facturé': False,
#   'Tarif horaire': 10,
#   'A facturer': True,
#   'Date de début': '2025-03-05',
#   'Cours': 'Innovation en IA & Transformation des organisations partie 1'},
#  {'Ville': 'Evry',
#   'Classe': 'M1 Maths',
#   'Date de fin': None,
#   'Total': 35,
#   'Ecole': 'ENSIIE',
#   'Nombre heures': 3.5,
#   'Facturé': False,
#   'Tarif horaire': 10,
#   'A facturer': True,
#   'Date de début': '2025-04-23',
#   'Cours': 'Régression linéaire session 1'},
#  {'Ville': 'Evry',
#   'Classe': 'L3',
#   'Date de fin': None,
#   'Total': 17.5,
#   'Ecole': 'ENSIIE',
#   'Nombre heures': 3.5,
#   'Facturé': False,
#   'Tarif horaire': 5,
#   'A facturer': True,
#   'Date de début': '2025-05-16',
#   'Cours': 'Mathématiques pour l’informatique session 2'},
#  {'Ville': 'Evry',
#   'Classe': 'L3',
#   'Date de fin': None,
#   'Total': 10,
#   'Ecole': 'ENSIIE',
#   'Nombre heures': 2,
#   'Facturé': False,
#   'Tarif horaire': 5,
#   'A facturer': False,
#   'Date de début': '2025-07-24',
#   'Cours': 'Mathématiques pour l’informatique examen blanc'},
#  {'Ville': 'Paris',
#   'Classe': 'BTS SIO',
#   'Date de fin': None,
#   'Total': 52.5,
#   'Ecole': 'NEXA Digital School',
#   'Nombre heures': 3.5,
#   'Facturé': False,
#   'Tarif horaire': 15,
#   'A facturer': False,
#   'Date de début': '2025-08-12',
#   'Cours': 'Mathématiques pour l’informatique session 5'},
#  {'Ville': 'Paris',
#   'Classe': 'BTS SIO',
#   'Date de fin': None,
#   'Total': 52.5,
#   'Ecole': 'NEXA Digital School',
#   'Nombre heures': 3.5,
#   'Facturé': False,
#   'Tarif horaire': 15,
#   'A facturer': True,
#   'Date de début': '2025-04-23',
#   'Cours': 'Mathématiques pour l’informatique session 1'},
#  {'Ville': 'Evry',
#   'Classe': 'L3',
#   'Date de fin': None,
#   'Total': 17.5,
#   'Ecole': 'ENSIIE',
#   'Nombre heures': 3.5,
#   'Facturé': False,
#   'Tarif horaire': 5,
#   'A facturer': True,
#   'Date de début': '2025-04-23',
#   'Cours': 'Mathématiques pour l’informatique session 1'},
#  {'Ville': 'Paris',
#   'Classe': 'BTS SIO',
#   'Date de fin': None,
#   'Total': 52.5,
#   'Ecole': 'ECE',
#   'Nombre heures': 3.5,
#   'Facturé': False,
#   'Tarif horaire': 15,
#   'A facturer': False,
#   'Date de début': '2025-07-02',
#   'Cours': 'Mathématiques pour l’informatique session 3'},
#  {'Ville': 'Paris',
#   'Classe': 'BTS SIO',
#   'Date de fin': None,
#   'Total': 52.5,
#   'Ecole': 'NEXA Digital School',
#   'Nombre heures': 3.5,
#   'Facturé': False,
#   'Tarif horaire': 15,
#   'A facturer': False,
#   'Date de début': '2025-08-21',
#   'Cours': 'Mathématiques pour l’informatique session 4'},
#  {'Ville': 'Evry',
#   'Classe': 'M1 Maths',
#   'Date de fin': None,
#   'Total': 17.5,
#   'Ecole': 'ENSIIE',
#   'Nombre heures': 3.5,
#   'Facturé': False,
#   'Tarif horaire': 5,
#   'A facturer': False,
#   'Date de début': '2025-08-12',
#   'Cours': 'Mathématiques pour l’informatique session 5'},
#  {'Ville': 'Evry',
#   'Classe': 'M1 Maths',
#   'Date de fin': None,
#   'Total': 35,
#   'Ecole': 'ENSIIE',
#   'Nombre heures': 3.5,
#   'Facturé': False,
#   'Tarif horaire': 10,
#   'A facturer': True,
#   'Date de début': '2025-05-16',
#   'Cours': 'Régression linéaire session 2'}]

# %% [markdown]
# Création d'un DataFrame pour afficher les résultats

# %%
df = pandas.DataFrame(results_json)
df
# Out:
#                  Ville    Classe Date de fin  Total                Ecole  \
# 0   Le Kremlin-Bicêtre        M1        None   70.0      EPITECH Digital
# 1                 Evry  M1 Maths        None   35.0               ENSIIE
# 2                Paris        M1        None   70.0                  ECE
# 3   Le Kremlin-Bicêtre        M1        None   70.0      EPITECH Digital
# 4                Paris        L3        None   52.5                  ECE
# 5                Paris   BTS SIO        None   52.5  NEXA Digital School
# 6                Paris   BTS SIO        None   52.5  NEXA Digital School
# 7       Noisy-le-Grand  M2 EDWEB  2025-05-03  140.0                ESIEE
# 8                 Evry  M1 Maths        None   17.5               ENSIIE
# 9                Paris        M1        None   70.0                  ECE
# 10               Paris        L3        None   52.5                  ECE
# 11                Evry  M1 Maths        None   20.0               ENSIIE
# 12               Paris        L3        None   52.5                  ECE
# 13                Evry  M1 EDWEB  2025-08-01  210.0               ENSIIE
# 14               Paris        L3        None   52.5                  ECE
# 15               Paris        L3  2025-07-30  210.0                  ECE
# 16               Paris   BTS SIO        None   30.0  NEXA Digital School
# 17                Evry        L3        None   17.5               ENSIIE
# 18                Evry        L3        None   70.0               ENSIIE
# 19                Evry        L3        None   35.0               ENSIIE
# 20               Paris        L3        None   30.0                  ECE
# 21      Noisy-le-Grand        M1  2025-06-13  140.0                ESIEE
# 22      Noisy-le-Grand        M1  2025-07-04  350.0                ESIEE
# 23  Le Kremlin-Bicêtre        M1        None   70.0      EPITECH Digital
# 24                Evry  M1 Maths        None   35.0               ENSIIE
# 25                Evry        L3        None   17.5               ENSIIE
# 26                Evry        L3        None   10.0               ENSIIE
# 27               Paris   BTS SIO        None   52.5  NEXA Digital School
# 28               Paris   BTS SIO        None   52.5  NEXA Digital School
# 29                Evry        L3        None   17.5               ENSIIE
# 30               Paris   BTS SIO        None   52.5                  ECE
# 31               Paris   BTS SIO        None   52.5  NEXA Digital School
# 32                Evry  M1 Maths        None   17.5               ENSIIE
# 33                Evry  M1 Maths        None   35.0               ENSIIE
#
#     Nombre heures  Facturé  Tarif horaire  A facturer Date de début  \
# 0             7.0    False             10        True    2025-03-19
# 1             3.5    False             10       False    2025-07-02
# 2             7.0    False             10        True    2025-03-05
# 3             7.0    False             10        True    2025-03-05
# 4             3.5    False             15        True    2025-05-16
# 5             3.5    False             15        True    2025-05-23
# 6             3.5    False             15       False    2025-07-09
# 7            28.0    False              5        True    2025-04-25
# 8             3.5    False              5       False    2025-08-07
# 9             7.0    False             10        True    2025-03-19
# 10            3.5    False             15       False    2025-08-12
# 11            2.0    False             10       False    2025-07-24
# 12            3.5    False             15        True    2025-04-23
# 13           14.0    False             15       False    2025-07-31
# 14            3.5    False             15       False    2025-08-07
# 15           14.0    False             15       False    2025-07-28
# 16            2.0    False             15       False    2025-07-31
# 17            3.5    False              5       False    2025-07-02
# 18            7.0    False             10       False    2025-08-14
# 19            3.5    False             10       False    2025-08-07
# 20            2.0    False             15       False    2025-07-24
# 21           28.0    False              5       False    2025-06-10
# 22           35.0    False             10       False    2025-06-30
# 23            7.0    False             10        True    2025-03-05
# 24            3.5    False             10        True    2025-04-23
# 25            3.5    False              5        True    2025-05-16
# 26            2.0    False              5       False    2025-07-24
# 27            3.5    False             15       False    2025-08-12
# 28            3.5    False             15        True    2025-04-23
# 29            3.5    False              5        True    2025-04-23
# 30            3.5    False             15       False    2025-07-02
# 31            3.5    False             15       False    2025-08-21
# 32            3.5    False              5       False    2025-08-12
# 33            3.5    False             10        True    2025-05-16
#
#                                                 Cours
# 0    Innovation en IA & Transformation des organis...
# 1                       Régression linéaire session 3
# 2   Innovation en IA & Transformation des organisa...
# 3   Innovation en IA & Transformation des organisa...
# 4         Mathématiques pour l’informatique session 2
# 5         Mathématiques pour l’informatique session 2
# 6         Mathématiques pour l’informatique session 3
# 7            Programmation avec Python - Introduction
# 8         Mathématiques pour l’informatique session 4
# 9    Innovation en IA & Transformation des organis...
# 10        Mathématiques pour l’informatique session 5
# 11                      Régression linéaire session 4
# 12    Mathématiques pour l’informatique session 1 (1)
# 13  Accessibilité des Données : Enjeux, Solutions ...
# 14        Mathématiques pour l’informatique session 4
# 15  Accessibilité des Données : Enjeux, Solutions ...
# 16     Mathématiques pour l’informatique examen blanc
# 17        Mathématiques pour l’informatique session 3
# 18                     Régression linéaire soutenance
# 19                      Régression linéaire session 5
# 20     Mathématiques pour l’informatique examen blanc
# 21  Programmation avec Python - Avancée (Orientée ...
# 22   A la découverte du framework TensorFlow de Go...
# 23  Innovation en IA & Transformation des organisa...
# 24                      Régression linéaire session 1
# 25        Mathématiques pour l’informatique session 2
# 26     Mathématiques pour l’informatique examen blanc
# 27        Mathématiques pour l’informatique session 5
# 28        Mathématiques pour l’informatique session 1
# 29        Mathématiques pour l’informatique session 1
# 30        Mathématiques pour l’informatique session 3
# 31        Mathématiques pour l’informatique session 4
# 32        Mathématiques pour l’informatique session 5
# 33                      Régression linéaire session 2

# %% [markdown]
# ## Par ville, le nombre d’écoles, le nombre d’heures données et la somme à facturer

# %%
df.groupby(['Ville']).agg({
    'Ecole': 'nunique',
    'Nombre heures': 'sum',
    'A facturer': 'sum'
}).reset_index()
# Out:
#                 Ville  Ecole  Nombre heures  A facturer
# 0                Evry      1           56.5           4
# 1  Le Kremlin-Bicêtre      1           21.0           3
# 2      Noisy-le-Grand      1           91.0           1
# 3               Paris      2           67.0           6

# %% [markdown]
# ## Par école et par classe, le nombre d’heures enseignées

# %%
df.groupby(['Ecole', 'Classe']).agg({
    'Nombre heures': 'sum'
}).reset_index()
# Out:
#                  Ecole    Classe  Nombre heures
# 0                  ECE   BTS SIO            3.5
# 1                  ECE        L3           30.0
# 2                  ECE        M1           14.0
# 3               ENSIIE        L3           23.0
# 4               ENSIIE  M1 EDWEB           14.0
# 5               ENSIIE  M1 Maths           19.5
# 6      EPITECH Digital        M1           21.0
# 7                ESIEE        M1           63.0
# 8                ESIEE  M2 EDWEB           28.0
# 9  NEXA Digital School   BTS SIO           19.5
